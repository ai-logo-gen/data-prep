# %% [markdown]
# # Datenbasis-Analyse für die Masterarbeit
#
# Dieses Notebook dient der exemplarischen Darstellung von zwei ausgewählten Logos und deren zugehörigen Metadaten. Die hier präsentierten Daten sind Teil der Grundlage für das Training des Diffusionsmodells.

# %%
import pandas as pd
from PIL import Image
from IPython.display import display, HTML
import os

# --- Konfiguration ---
METADATA_PATH = '../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata2.csv'
IMAGE_DIR = '../output/amazing_logos_v4/images/balanced_sample_2k_512x512'
IDS_TO_DISPLAY = ['amazing_logo_v4000185', 'amazing_logo_v4054788']

# --- Daten laden ---
try:
    df = pd.read_csv(METADATA_PATH)
    print("Metadaten erfolgreich geladen.")
except FileNotFoundError:
    print(f"Fehler: Die Datei {METADATA_PATH} wurde nicht gefunden.")
    df = None
# Out:
# Metadaten erfolgreich geladen.

# %%
df
# Out:
#                            id                                         company  \
# 0       amazing_logo_v4000000       Simple elegant logo for Mandarin Oriental
# 1       amazing_logo_v4000001                    Simple elegant logo for Alfa
# 2       amazing_logo_v4000002                 Simple elegant logo for Kuraray
# 3       amazing_logo_v4000003            Simple elegant logo for Valwood Park
# 4       amazing_logo_v4000004                 Simple elegant logo for Cinepaq
# ...                       ...                                             ...
# 393293  amazing_logo_v4397246            Simple elegant logo for Peak2Pacific
# 393294  amazing_logo_v4397247            Simple elegant logo for VisionOttica
# 393295  amazing_logo_v4397248           Simple elegant logo for Elite Angling
# 393296  amazing_logo_v4397249          Simple elegant logo for Jacki Ms & Son
# 393297  amazing_logo_v4397250  Simple elegant logo for Cecchetti Wine Company
#
#                                          description         category  \
# 0                          Fan Hong kong Lines Paper      Hospitality
# 1                           Hexagon Poland Triangles        Chemicals
# 2                                  G Japan K Outline      Safty Glass
# 3                      Lines Rounded United states V             Park
# 4                    C Circle Film reel Spain Square             Film
# ...                                              ...              ...
# 393293                      Wave Mountains Adventure           Health
# 393294                                    eye People     Optic retail
# 393295                 fishing fish boat truck drive  Fishing Charter
# 393296    Logo Icon Legs Pie Cooper Woman Restaurant       Restaurant
# 393297  sans red black serif Monogram and typography             Wine
#
#                                                      tags
# 0       successful vibe, minimalist, thought-provoking...
# 1       successful vibe, minimalist, thought-provoking...
# 2       successful vibe, minimalist, thought-provoking...
# 3       successful vibe, minimalist, thought-provoking...
# 4       successful vibe, minimalist, thought-provoking...
# ...                                                   ...
# 393293  Wellness, Outdoor Adventure, successful vibe, ...
# 393294  successful vibe, minimalist, thought-provoking...
# 393295  successful vibe, minimalist, thought-provoking...
# 393296  successful vibe, minimalist, thought-provoking...
# 393297  successful vibe, minimalist, thought-provoking...
#
# [393298 rows x 5 columns]
