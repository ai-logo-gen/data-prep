# %% [markdown]
# # Filter Metadata by Available Maps
#
# This notebook:
# 1. Loads `metadata10.csv`.
# 2. Lists available map images in `balanced_sample_2k_512x512_maps`.
# 3. Filters the metadata to include only rows for which a map image exists.
# 4. Saves the result as `metadata_filtered_by_maps.csv` with reordered columns.

# %%
# Imports & Paths
from pathlib import Path
import pandas as pd
import os

BASE_PATH = Path(__file__).resolve().parent if '__file__' in globals() else Path.cwd()
PROJECT_ROOT = BASE_PATH / '../..'
META_PATH = PROJECT_ROOT / 'output' / 'amazing_logos_v4' / 'data' / 'amazing_logos_v4_image_prep' / 'metadata10.csv'
MAPS_DIR = PROJECT_ROOT / 'output' / 'amazing_logos_v4' / 'images' / 'balanced_sample_2k_512x512_maps'
OUTPUT_DATA_DIR = PROJECT_ROOT / 'output' / 'amazing_logos_v4' / 'data'
OUTPUT_DATA_DIR.mkdir(parents=True, exist_ok=True)
FINAL_PATH = OUTPUT_DATA_DIR / 'meta_postprep' /'metadata_filtered_by_maps.csv'

print('Metadata path:', META_PATH)
print('Maps dir     :', MAPS_DIR)
print('Output dir   :', OUTPUT_DATA_DIR)

metadata = pd.read_csv(META_PATH)
print('Loaded metadata rows:', len(metadata))
metadata.head()
# Out:
# Metadata path: c:\studium\master_thesis\data_prep\notebooks\meta_postprep\..\..\output\amazing_logos_v4\data\amazing_logos_v4_image_prep\metadata10.csv
# Maps dir     : c:\studium\master_thesis\data_prep\notebooks\meta_postprep\..\..\output\amazing_logos_v4\images\balanced_sample_2k_512x512_maps
# Output dir   : c:\studium\master_thesis\data_prep\notebooks\meta_postprep\..\..\output\amazing_logos_v4\data
# Loaded metadata rows: 177224
# Loaded metadata rows: 177224
#                       id                                       company  \
# 0  amazing_logo_v4000000     Simple elegant logo for Mandarin Oriental
# 1  amazing_logo_v4000001                  Simple elegant logo for Alfa
# 2  amazing_logo_v4000003          Simple elegant logo for Valwood Park
# 3  amazing_logo_v4000004               Simple elegant logo for Cinepaq
# 4  amazing_logo_v4000005  Simple elegant logo for Baumechanik Barleben
#
#                        description            category  \
# 0        Fan Hong kong Lines Paper      hotels_lodging
# 1         Hexagon Poland Triangles  chemical_materials
# 2    Lines Rounded United states V        unclassified
# 3  C Circle Film reel Spain Square          film_video
# 4                 B Circle Germany        unclassified
#
#                                                 tags  \
# 0  successful_vibe,minimalist,thoughtprovoking,ab...
# 1  successful_vibe,minimalist,thoughtprovoking,ab...
# 2  successful_vibe, minimalist, thoughtprovoking,...
# 3  successful_vibe,minimalist,thoughtprovoking,ab...
# 4  successful_vibe, minimalist, thoughtprovoking,...
#
#                 category_main
# 0          retail_hospitality
# 1     manufacturing_transport
# 2                       other
# 3  entertainment_sports_media
# 4                       other

# %%
# Collect map image IDs
SUPPORTED_EXTS = {'.png', '.jpg', '.jpeg', '.webp'}
map_ids = []
if MAPS_DIR.exists():
    for p in MAPS_DIR.iterdir():
        if p.is_file() and p.suffix.lower() in SUPPORTED_EXTS:
            map_ids.append(p.stem)
else:
    raise FileNotFoundError(f"Maps directory not found: {MAPS_DIR}")

map_ids = sorted(set(map_ids))
print('Found map images:', len(map_ids))
map_ids[:5]
# Out:
# Found map images: 1810
# ['amazing_logo_v4000185',
#  'amazing_logo_v4000313',
#  'amazing_logo_v4000469',
#  'amazing_logo_v4000481',
#  'amazing_logo_v4000523']

# %%
# Filter metadata rows to those with matching IDs
filtered = metadata[metadata['id'].isin(map_ids)].copy()
print('Filtered rows:', len(filtered))

missing_from_maps = set(metadata['id']) - set(filtered['id'])
print('Metadata rows without map image:', len(missing_from_maps))
filtered.head()
# Out:
# Filtered rows: 1810
# Metadata rows without map image: 175414
#                         id                                     company  \
# 105  amazing_logo_v4000185  Simple elegant logo for Santa Fe By Design
# 174  amazing_logo_v4000313       Simple elegant logo for Bluebird Cafe
# 257  amazing_logo_v4000469      Simple elegant logo for Collezione Nai
# 264  amazing_logo_v4000481      Simple elegant logo for Renault Alpine
# 289  amazing_logo_v4000523            Simple elegant logo for Rotation
#
#                                    description                category  \
# 105              Drop Oval United states Water  textiles_manufacturing
# 174                    Bird Fork United states       restaurant_dining
# 257                                A I Italy N        home_improvement
# 264               A Arrow France Line Triangle    automotive_transport
# 289  Circle Germany Line Rotation Spiral Swirl            arts_culture
#
#                                                   tags  \
# 105  successful_vibe,minimalist,thoughtprovoking,ab...
# 174  successful_vibe,minimalist,thoughtprovoking,ab...
# 257  successful_vibe,minimalist,thoughtprovoking,ab...
# 264  successful_vibe,minimalist,thoughtprovoking,ab...
# 289  successful_vibe,minimalist,thoughtprovoking,ab...
#
#                   category_main
# 105     manufacturing_transport
# 174               food_beverage
# 257          retail_hospitality
# 264     manufacturing_transport
# 289  entertainment_sports_media

# %%
# Reorder columns and save
final_cols = ['id','category_main','category','description','tags','company']
missing_cols = [c for c in final_cols if c not in filtered.columns]
if missing_cols:
    raise KeyError(f"Missing expected columns: {missing_cols}")

final_df = filtered[final_cols].copy()
final_df.to_csv(FINAL_PATH, index=False)
print(f"Saved final metadata: {FINAL_PATH} ({len(final_df)} rows)")
final_df.head()
# Out:
# Saved final metadata: c:\studium\master_thesis\data_prep\notebooks\meta_postprep\..\..\output\amazing_logos_v4\data\meta_postprep\metadata_filtered_by_maps.csv (1810 rows)
#                         id               category_main  \
# 105  amazing_logo_v4000185     manufacturing_transport
# 174  amazing_logo_v4000313               food_beverage
# 257  amazing_logo_v4000469          retail_hospitality
# 264  amazing_logo_v4000481     manufacturing_transport
# 289  amazing_logo_v4000523  entertainment_sports_media
#
#                    category                                description  \
# 105  textiles_manufacturing              Drop Oval United states Water
# 174       restaurant_dining                    Bird Fork United states
# 257        home_improvement                                A I Italy N
# 264    automotive_transport               A Arrow France Line Triangle
# 289            arts_culture  Circle Germany Line Rotation Spiral Swirl
#
#                                                   tags  \
# 105  successful_vibe,minimalist,thoughtprovoking,ab...
# 174  successful_vibe,minimalist,thoughtprovoking,ab...
# 257  successful_vibe,minimalist,thoughtprovoking,ab...
# 264  successful_vibe,minimalist,thoughtprovoking,ab...
# 289  successful_vibe,minimalist,thoughtprovoking,ab...
#
#                                         company
# 105  Simple elegant logo for Santa Fe By Design
# 174       Simple elegant logo for Bluebird Cafe
# 257      Simple elegant logo for Collezione Nai
# 264      Simple elegant logo for Renault Alpine
# 289            Simple elegant logo for Rotation
