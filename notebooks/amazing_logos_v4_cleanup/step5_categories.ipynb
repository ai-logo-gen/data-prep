# %% [markdown]
# # Amazing Logos V4 - Step 5: Categories Final Cleanup
#
# This notebook performs final category cleanup:
# - Loads metadata8.csv
# - Changes categories to 'unclassified' if they're not in the consolidation_map.keys()
# - For frequent unclassified categories (>5 occurrences), adds the original category to tags
# - Saves the result as metadata9.csv

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
from collections import Counter

# Add utils folder to path
utils_path = Path('../../utils')
sys.path.append(str(utils_path))

# Import consolidation functions
from consolidation import consolidate_categories, normalize_category, consolidation_map

# Paths
input_metadata_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata8.csv')
output_metadata_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata9.csv')

print(f"Input metadata CSV: {input_metadata_csv}")
print(f"Output metadata CSV: {output_metadata_csv}")

# Check if metadata input exists
if not input_metadata_csv.exists():
    print(f"ERROR: Input file {input_metadata_csv} does not exist!")
else:
    print(f"Input metadata file exists.")
# Out:
# Input metadata CSV: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata8.csv
# Output metadata CSV: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata9.csv
# Input metadata file exists.

# %%
# Load metadata
print("Loading metadata...")
df = pd.read_csv(input_metadata_csv)

print(f"Loaded metadata: {len(df):,} rows")
print(f"Columns: {list(df.columns)}")

# Display basic info about categories
print(f"\nUnique categories before cleanup: {df['category'].nunique()}")
print(f"\nTop 10 current categories:")
category_counts = df['category'].value_counts()
for i, (cat, count) in enumerate(category_counts.head(10).items(), 1):
    percentage = (count / len(df)) * 100
    print(f"{i:2d}. {cat:<30} {count:>7} ({percentage:>5.2f}%)")

# Show categories with NA values
na_count = df['category'].isna().sum()
print(f"\nNA categories: {na_count}")
# Out:
# Loading metadata...
# Loaded metadata: 352,154 rows
# Columns: ['id', 'company', 'description', 'category', 'tags']
#
# Unique categories before cleanup: 1622
#
# Top 10 current categories:
#  1. unclassified                     29442 ( 8.36%)
#  2. sports_recreation                11383 ( 3.23%)
#  3. restaurant_dining                10963 ( 3.11%)
#  4. real_estate_residential          10825 ( 3.07%)
#  5. healthcare_general               10534 ( 2.99%)
#  6. design_creative                  10366 ( 2.94%)
#  7. nonprofit_charity                10134 ( 2.88%)
#  8. fashion_apparel                   9174 ( 2.61%)
#  9. education_k12                     8572 ( 2.43%)
# 10. food                              7866 ( 2.23%)
#
# NA categories: 0

# %%
# Check what categories are valid according to consolidation_map
valid_categories = set(consolidation_map.keys())
print(f"Valid categories from consolidation_map: {len(valid_categories)}")
print(f"\nValid categories list:")
for i, cat in enumerate(sorted(valid_categories), 1):
    print(f"{i:2d}. {cat}")

# Check current categories vs valid categories
current_categories = set(df['category'].dropna().astype(str))
print(f"\nCurrent unique categories (non-NA): {len(current_categories)}")

# Find categories that are already valid
already_valid = current_categories.intersection(valid_categories)
print(f"Categories already in consolidation_map: {len(already_valid)}")

# Find categories that need to be changed to unclassified
to_unclassify = current_categories - valid_categories
print(f"Categories to be changed to 'unclassified': {len(to_unclassify)}")

if to_unclassify:
    print(f"\nSample categories to be unclassified:")
    sample_to_unclassify = list(to_unclassify)[:20]
    for cat in sample_to_unclassify:
        count = category_counts.get(cat, 0)
        print(f"  {cat} ({count} occurrences)")
    if len(to_unclassify) > 20:
        print(f"  ... and {len(to_unclassify) - 20} more")
# Out:
# Valid categories from consolidation_map: 109
#
# Valid categories list:
#  1. accounting_tax
#  2. aerospace_defense
#  3. agriculture_farming
#  4. animal_services
#  5. arts_culture
#  6. auto_services
#  7. automotive_transport
#  8. aviation_services
#  9. bar_nightlife
# 10. beauty_cosmetics
# 11. beverage_general
# 12. brewery_alcohol
# 13. cafe_coffee
# 14. catering_events
# 15. chemical_materials
# 16. childcare_youth
# 17. cleaning_maintenance
# 18. community_social
# 19. construction_general
# 20. construction_home
# 21. construction_materials
# 22. construction_specialty
# 23. consulting_business
# 24. data_analytics
# 25. dental_services
# 26. design_creative
# 27. ecommerce_online
# 28. education_k12
# 29. educational_services
# 30. energy_utilities
# 31. entertainment_venues
# 32. environmental_services
# 33. event_services
# 34. fashion_apparel
# 35. film_video
# 36. financial_services
# 37. fintech_crypto
# 38. fitness_health
# 39. food_production
# 40. footwear_leather
# 41. forestry_lumber
# 42. funeral_services
# 43. gambling_betting
# 44. gaming_entertainment
# 45. government_public
# 46. grocery_retail
# 47. health_wellness
# 48. healthcare_general
# 49. higher_education
# 50. home_goods
# 51. home_improvement
# 52. home_services
# 53. hospitality_services
# 54. hotels_lodging
# 55. human_resources
# 56. import_export
# 57. insurance_services
# 58. it_services
# 59. jewelry_accessories
# 60. landscaping_garden
# 61. legal_services
# 62. lifestyle_personal
# 63. manufacturing_general
# 64. marine_services
# 65. marketing_advertising
# 66. martial_arts
# 67. media_publishing
# 68. medical_specialty
# 69. mental_health
# 70. mining_extraction
# 71. music_industry
# 72. nonprofit_charity
# 73. other_services
# 74. outdoor_sports
# 75. personal_professional
# 76. pet_services
# 77. photography_video
# 78. printing_publishing
# 79. property_management
# 80. radio_podcast
# 81. real_estate_commercial
# 82. real_estate_development
# 83. real_estate_residential
# 84. religious_faith
# 85. restaurant_dining
# 86. retail_general
# 87. salon_spa
# 88. security_safety
# 89. skateboarding_action
# 90. software_development
# 91. sports_recreation
# 92. sports_teams
# 93. tattoo body_art
# 94. tattoo_body_art
# 95. tech_hardware
# 96. telecommunications
# 97. textiles_manufacturing
# 98. tobacco_vaping
# 99. training_development
# 100. transportation_services
# 101. travel_tourism
# 102. unclassified
# 103. vacation_recreation
# 104. vehicle_sales
# 105. veterinary
# 106. water_services
# 107. web_digital
# 108. wellness_fitness
# 109. wholesale_distribution
#
# Current unique categories (non-NA): 1622
# Categories already in consolidation_map: 109
# Categories to be changed to 'unclassified': 1513
#
# Sample categories to be unclassified:
#   arrow (4 occurrences)
#   home_development (14 occurrences)
#   guiding (4 occurrences)
#   neighborhood_association (22 occurrences)
#   professional_basketball (16 occurrences)
#   financing (46 occurrences)
#   ply (5 occurrences)
#   signmaking (4 occurrences)
#   cooking (43 occurrences)
#   crossfit (15 occurrences)
#   children_retail_clothing (4 occurrences)
#   design_furnishings (16 occurrences)
#   baby_products (47 occurrences)
#   color_management (4 occurrences)
#   horror_convention (4 occurrences)
#   monogram (19 occurrences)
#   industrial_gauges (4 occurrences)
#   promotional_merchandise (4 occurrences)
#   community_organization (19 occurrences)
#   food_and_drink (117 occurrences)
#   ... and 1493 more

# %%
# Find frequent categories that will become unclassified (>5 occurrences)
frequent_unclassified = []
for cat in to_unclassify:
    count = category_counts.get(cat, 0)
    if count > 5:
        frequent_unclassified.append((cat, count))

# Sort by frequency
frequent_unclassified.sort(key=lambda x: x[1], reverse=True)

print(f"Frequent categories (>5 occurrences) that will become 'unclassified': {len(frequent_unclassified)}")
print(f"These will be added to tags list:\n")

total_logos_to_tag = 0
for cat, count in frequent_unclassified:
    total_logos_to_tag += count
    print(f"  {cat:<40} {count:>6} occurrences")

print(f"\nTotal logos that will get original category added to tags: {total_logos_to_tag:,}")

# Create set for quick lookup
frequent_unclassified_set = {cat for cat, _ in frequent_unclassified}
# Out:
# Frequent categories (>5 occurrences) that will become 'unclassified': 1101
# These will be added to tags list:
#
#   food                                       7866 occurrences
#   financial                                  2263 occurrences
#   inc                                         785 occurrences
#   cannabis                                    735 occurrences
#   engineering                                 719 occurrences
#   tech                                        620 occurrences
#   graphic                                     415 occurrences
#   bank                                        340 occurrences
#   toys                                        336 occurrences
#   science                                     283 occurrences
#   housing_development                         276 occurrences
#   blog                                        225 occurrences
#   corporate                                   211 occurrences
#   auto                                        204 occurrences
#   music_entertainment                         200 occurrences
#   interior                                    195 occurrences
#   packaging                                   183 occurrences
#   paper                                       176 occurrences
#   trade                                       173 occurrences
#   health_beauty                               165 occurrences
#   high_tech                                   164 occurrences
#   health_and_beauty                           162 occurrences
#   consumer_products                           146 occurrences
#   foods                                       143 occurrences
#   toy                                         139 occurrences
#   racing                                      139 occurrences
#   library                                     138 occurrences
#   parks_recreation                            138 occurrences
#   personal_monogram                           136 occurrences
#   literature                                  130 occurrences
#   economic_development                        129 occurrences
#   news                                        128 occurrences
#   nature                                      121 occurrences
#   food_and_drink                              117 occurrences
#   industry                                    110 occurrences
#   pet_food                                    110 occurrences
#   rock_band                                   109 occurrences
#   copywriting                                 107 occurrences
#   consumer_goods                              103 occurrences
#   clothing_apparel                            100 occurrences
#   sales                                       100 occurrences
#   philanthropy                                100 occurrences
#   nonprofit_organization                       99 occurrences
#   advertisement                                98 occurrences
#   storage                                      97 occurrences
#   editorial                                    97 occurrences
#   food_beverages                               95 occurrences
#   agency                                       90 occurrences
#   floral                                       90 occurrences
#   college_athletics                            90 occurrences
#   social_network                               88 occurrences
#   design_firm                                  86 occurrences
#   personal_project                             85 occurrences
#   pet_industry                                 85 occurrences
#   multimedia                                   84 occurrences
#   creative_agency                              84 occurrences
#   proposed                                     83 occurrences
#   utility                                      83 occurrences
#   architects                                   83 occurrences
#   fmcg                                         83 occurrences
#   surf                                         82 occurrences
#   landscape_design                             81 occurrences
#   fb                                           80 occurrences
#   exhibition                                   80 occurrences
#   dating                                       80 occurrences
#   gastronomy                                   79 occurrences
#   personal_chef                                79 occurrences
#   product                                      75 occurrences
#   community_development                        75 occurrences
#   studio                                       75 occurrences
#   hair                                         75 occurrences
#   publication                                  74 occurrences
#   writer                                       73 occurrences
#   personal_symbol                              72 occurrences
#   bookstore                                    72 occurrences
#   greeting_cards                               72 occurrences
#   culinary                                     72 occurrences
#   music_festival                               71 occurrences
#   ceramics                                     68 occurrences
#   optometry                                    67 occurrences
#   cbd                                          66 occurrences
#   proposal                                     66 occurrences
#   startup                                      64 occurrences
#   parks_and_recreation                         64 occurrences
#   human_rights                                 64 occurrences
#   computer_software                            64 occurrences
#   equestrian                                   63 occurrences
#   church_environments                          62 occurrences
#   paper_products                               62 occurrences
#   solar_energy                                 61 occurrences
#   christian_ministry                           61 occurrences
#   food_delivery                                61 occurrences
#   internet_marketing                           60 occurrences
#   eric_rob_and_isaac_ad_guys                   60 occurrences
#   glass                                        60 occurrences
#   pet_products                                 60 occurrences
#   innovation                                   58 occurrences
#   city_government                              58 occurrences
#   internet_industry                            58 occurrences
#   craft_brewing                                57 occurrences
#   flowers                                      57 occurrences
#   barbershop                                   57 occurrences
#   entertainment_and_arts                       56 occurrences
#   chamber_of_commerce                          56 occurrences
#   halloween                                    55 occurrences
#   screen_printing                              55 occurrences
#   consumer                                     55 occurrences
#   holding_company                              54 occurrences
#   old_rabbit_design_studio                     54 occurrences
#   golf_apparel                                 54 occurrences
#   collegiate                                   53 occurrences
#   archery                                      53 occurrences
#   clothing_brand                               53 occurrences
#   web_hosting                                  53 occurrences
#   recording                                    51 occurrences
#   christian_church                             51 occurrences
#   apparel_clothing                             50 occurrences
#   optical                                      50 occurrences
#   dds                                          50 occurrences
#   business_networking                          50 occurrences
#   internet_services                            50 occurrences
#   computer_technology                          50 occurrences
#   interiors                                    50 occurrences
#   grocery_store                                49 occurrences
#   sports_equipment                             49 occurrences
#   community_theatre                            49 occurrences
#   fine_arts                                    49 occurrences
#   typography                                   48 occurrences
#   furniture_design                             48 occurrences
#   kettlebell_sport                             48 occurrences
#   sports_and_higher_education                  48 occurrences
#   baby_products                                47 occurrences
#   financing                                    46 occurrences
#   bicycle                                      46 occurrences
#   family                                       46 occurrences
#   worldwide_licensing                          46 occurrences
#   online_marketing                             46 occurrences
#   gift_boutique_wholesaler                     46 occurrences
#   office_furniture                             45 occurrences
#   tv_show                                      45 occurrences
#   self_help                                    44 occurrences
#   podcasting                                   44 occurrences
#   graphics                                     44 occurrences
#   car                                          44 occurrences
#   sports_fitness                               44 occurrences
#   cooking                                      43 occurrences
#   bike_shop                                    43 occurrences
#   entertainment_music                          43 occurrences
#   music_and_entertainment                      43 occurrences
#   dental_clinic                                43 occurrences
#   firearms                                     43 occurrences
#   consumer_retail                              42 occurrences
#   grooming                                     42 occurrences
#   online_community                             42 occurrences
#   consultation                                 42 occurrences
#   cyber_security                               42 occurrences
#   arts_and_entertainment                       42 occurrences
#   cpg                                          42 occurrences
#   solar_power                                  42 occurrences
#   gallery                                      42 occurrences
#   food_bev                                     42 occurrences
#   internet_radio                               42 occurrences
#   film_festival                                41 occurrences
#   products                                     41 occurrences
#   coffee_roaster                               41 occurrences
#   pharmaceutical_industry                      41 occurrences
#   personal_logo                                41 occurrences
#   cars                                         40 occurrences
#   public_library                               40 occurrences
#   space                                        40 occurrences
#   design_marketing                             40 occurrences
#   care                                         40 occurrences
#   hair_stylist                                 40 occurrences
#   personal_trainer                             39 occurrences
#   industrial_manufacturing                     39 occurrences
#   trade_association                            39 occurrences
#   the_arts                                     39 occurrences
#   candles                                      39 occurrences
#   lawncare                                     39 occurrences
#   music_label                                  39 occurrences
#   water_sports                                 39 occurrences
#   home_remodeling                              39 occurrences
#   flower_shop                                  39 occurrences
#   produce                                      38 occurrences
#   medical_care                                 38 occurrences
#   production_company                           38 occurrences
#   plastic_surgery                              38 occurrences
#   church_ministry                              37 occurrences
#   wine_and_spirits                             37 occurrences
#   goverment                                    37 occurrences
#   luxury                                       37 occurrences
#   automation                                   37 occurrences
#   beer_brewing                                 37 occurrences
#   musical_instruments                          37 occurrences
#   broadcast_television                         37 occurrences
#   commercial_construction                      37 occurrences
#   dry_cleaning                                 36 occurrences
#   sports_club                                  36 occurrences
#   information                                  36 occurrences
#   creative_arts                                36 occurrences
#   comedy                                       36 occurrences
#   signage                                      36 occurrences
#   liquor_store                                 35 occurrences
#   railroad                                     35 occurrences
#   business_consultancy                         35 occurrences
#   sports_medicine                              35 occurrences
#   public_power                                 35 occurrences
#   britain                                      35 occurrences
#   maritime                                     35 occurrences
#   ncaa_sports                                  35 occurrences
#   photo                                        35 occurrences
#   film_and_entertainment                       34 occurrences
#   business_consultant                          34 occurrences
#   education_athletics                          34 occurrences
#   university_athletics                         33 occurrences
#   motivational_speaking                        33 occurrences
#   ad_agency                                    33 occurrences
#   turism                                       33 occurrences
#   beer_brewery                                 33 occurrences
#   sports_marketing                             33 occurrences
#   management_consultancy                       33 occurrences
#   sports_and_fitness                           33 occurrences
#   alternative_energy                           33 occurrences
#   b2b                                          33 occurrences
#   green_energy                                 33 occurrences
#   retail_fashion                               32 occurrences
#   gas_station                                  32 occurrences
#   apparel_company                              32 occurrences
#   institutional                                32 occurrences
#   sporting                                     32 occurrences
#   promo                                        32 occurrences
#   law_enforcement                              32 occurrences
#   daggerfin                                    31 occurrences
#   neighborhood                                 31 occurrences
#   government_agency                            31 occurrences
#   baked_goods                                  31 occurrences
#   childrens_toys                               31 occurrences
#   sporting_goods_retail                        31 occurrences
#   medical_insurance                            31 occurrences
#   snowboards                                   31 occurrences
#   camp                                         31 occurrences
#   chiropractor                                 31 occurrences
#   film_industry                                31 occurrences
#   agroindustry                                 31 occurrences
#   comic_book                                   30 occurrences
#   advertising_and_design                       30 occurrences
#   wear                                         30 occurrences
#   sports_collectibles                          30 occurrences
#   alimentos                                    30 occurrences
#   ltd                                          30 occurrences
#   parks                                        30 occurrences
#   licensing                                    30 occurrences
#   life_sciences                                30 occurrences
#   irish_dancing                                30 occurrences
#   holding                                      30 occurrences
#   social_club                                  30 occurrences
#   hemp                                         30 occurrences
#   ski_resort                                   30 occurrences
#   hospice                                      30 occurrences
#   speaking                                     30 occurrences
#   retirement                                   30 occurrences
#   pet_shop                                     29 occurrences
#   fashion_clothing                             29 occurrences
#   technology_consulting                        29 occurrences
#   promotional_products                         29 occurrences
#   yoga_studio                                  29 occurrences
#   building_industry                            29 occurrences
#   mark                                         29 occurrences
#   disc_golf                                    29 occurrences
#   wine_spirits                                 29 occurrences
#   consulting_company                           29 occurrences
#   public_speaking                              29 occurrences
#   construction_management                      29 occurrences
#   auto_racing                                  28 occurrences
#   cosmetic_dentistry                           28 occurrences
#   inktober                                     28 occurrences
#   technology_communications                    28 occurrences
#   biking                                       28 occurrences
#   interactive_agency                           28 occurrences
#   customer_service                             28 occurrences
#   photography_studio                           28 occurrences
#   dairy_products                               28 occurrences
#   copywriter                                   28 occurrences
#   womens_health                                28 occurrences
#   decoration                                   28 occurrences
#   structures                                   28 occurrences
#   distilling                                   28 occurrences
#   fundraiser                                   28 occurrences
#   pro_bono                                     27 occurrences
#   marketing_and_design                         27 occurrences
#   apartment_community                          27 occurrences
#   housing_estate                               27 occurrences
#   internet_security                            27 occurrences
#   language                                     27 occurrences
#   healthcare_technology                        27 occurrences
#   place_marketing_local_government             27 occurrences
#   letterpress_printing                         27 occurrences
#   mortgage_broker                              27 occurrences
#   printing_house                               27 occurrences
#   art_education                                27 occurrences
#   video_gaming                                 26 occurrences
#   social_work                                  26 occurrences
#   nutritional_supplements                      26 occurrences
#   gourmet_foods                                26 occurrences
#   bottled_water                                26 occurrences
#   sporting_event                               26 occurrences
#   entertaiment                                 26 occurrences
#   institution                                  26 occurrences
#   fly_fishing                                  26 occurrences
#   direct_mail                                  26 occurrences
#   rock_paper_scissors                          26 occurrences
#   investing                                    26 occurrences
#   graphic_arts                                 26 occurrences
#   tv_station                                   26 occurrences
#   hair_styling                                 26 occurrences
#   signs                                        26 occurrences
#   energy_supplier                              26 occurrences
#   education_animation                          26 occurrences
#   pharamacutical                               26 occurrences
#   wedding_planner                              25 occurrences
#   childrens_products                           25 occurrences
#   nautical                                     25 occurrences
#   delivery_services                            25 occurrences
#   electrical_engineering                       25 occurrences
#   transportation_logistics                     25 occurrences
#   art_exhibition                               25 occurrences
#   restaraunt                                   25 occurrences
#   firm                                         25 occurrences
#   restuarant_concept                           25 occurrences
#   soap                                         25 occurrences
#   eco                                          25 occurrences
#   charitable_foundation                        25 occurrences
#   international_marine_animal_trainers_association     25 occurrences
#   disability_services                          25 occurrences
#   professional_baseball                        25 occurrences
#   gourmet_food                                 25 occurrences
#   symbol                                       24 occurrences
#   furniture_store                              24 occurrences
#   bicycles                                     24 occurrences
#   veterinary_services                          24 occurrences
#   business_to_business                         24 occurrences
#   mortgage_lending                             24 occurrences
#   wedding_monogram                             24 occurrences
#   strategy                                     24 occurrences
#   investment_management                        24 occurrences
#   food_and_wine                                24 occurrences
#   wireless_communications                      24 occurrences
#   news_media                                   24 occurrences
#   adoption                                     24 occurrences
#   retail_sales                                 24 occurrences
#   hi_tech                                      24 occurrences
#   public_transport                             24 occurrences
#   retirement_community                         24 occurrences
#   school_mascot                                24 occurrences
#   awards                                       24 occurrences
#   equipment                                    24 occurrences
#   investment_company                           24 occurrences
#   embroidery                                   24 occurrences
#   sports_training                              24 occurrences
#   business_consultants                         24 occurrences
#   it_solutions                                 24 occurrences
#   golf_club                                    23 occurrences
#   computer_networking                          23 occurrences
#   communication_agency                         23 occurrences
#   vending                                      23 occurrences
#   quilting                                     23 occurrences
#   laundry                                      23 occurrences
#   homebuilding                                 23 occurrences
#   hot_sauce                                    23 occurrences
#   audio_visual                                 23 occurrences
#   sewing                                       23 occurrences
#   hotel_leisure                                23 occurrences
#   conferencing                                 23 occurrences
#   comic_books                                  23 occurrences
#   public_transportation                        23 occurrences
#   stock_photography                            23 occurrences
#   community_center                             23 occurrences
#   robotics                                     23 occurrences
#   professional_association                     23 occurrences
#   charitable                                   23 occurrences
#   music_publishing                             23 occurrences
#   youth_ministry                               23 occurrences
#   paper_manufacturing                          23 occurrences
#   event_theater                                23 occurrences
#   olive_oil                                    23 occurrences
#   home_automation                              23 occurrences
#   india                                        23 occurrences
#   ll                                           23 occurrences
#   adult_entertainment                          23 occurrences
#   accountancy                                  23 occurrences
#   email_marketing                              23 occurrences
#   web_agency                                   23 occurrences
#   neighborhood_association                     22 occurrences
#   general_use                                  22 occurrences
#   flower                                       22 occurrences
#   prostate_cancer_awareness                    22 occurrences
#   wedding_and_event_planning                   22 occurrences
#   medical_clinic                               22 occurrences
#   diplomacy                                    22 occurrences
#   wine_bar                                     22 occurrences
#   private                                      22 occurrences
#   service_industry                             22 occurrences
#   post_production                              22 occurrences
#   history                                      22 occurrences
#   medical_spa                                  22 occurrences
#   equine                                       22 occurrences
#   creative_media                               22 occurrences
#   school_athletics                             22 occurrences
#   music_retail                                 22 occurrences
#   texas                                        22 occurrences
#   metal_fabrication                            22 occurrences
#   small_business                               22 occurrences
#   nanotechnology                               22 occurrences
#   floral_design                                22 occurrences
#   biomedical                                   22 occurrences
#   music_producer                               22 occurrences
#   multimedia_development                       22 occurrences
#   dog_grooming                                 22 occurrences
#   direct_marketing                             22 occurrences
#   national_parks                               22 occurrences
#   consumer_products_design                     22 occurrences
#   sports_hockey                                22 occurrences
#   hotel_industry                               22 occurrences
#   marketing_research                           22 occurrences
#   town                                         21 occurrences
#   japanese_restaurant                          21 occurrences
#   amusement_rides                              21 occurrences
#   state_university                             21 occurrences
#   country_club                                 21 occurrences
#   ong                                          21 occurrences
#   paper_manufacturer                           21 occurrences
#   winegrower                                   21 occurrences
#   hair_and_beauty                              21 occurrences
#   sport_fitness                                21 occurrences
#   website_development                          21 occurrences
#   activism                                     21 occurrences
#   science_research                             21 occurrences
#   motocross                                    21 occurrences
#   motivational_speaker                         21 occurrences
#   parking                                      21 occurrences
#   metalworks                                   21 occurrences
#   institute                                    21 occurrences
#   publishing_industry                          21 occurrences
#   fashion_jewelry                              21 occurrences
#   merchandising                                21 occurrences
#   weather                                      21 occurrences
#   furniture_manufacturing                      21 occurrences
#   event_agency                                 21 occurrences
#   contruction                                  21 occurrences
#   medical_software                             21 occurrences
#   sports_clothing                              21 occurrences
#   speaker                                      21 occurrences
#   retail_goods                                 21 occurrences
#   headwear                                     21 occurrences
#   shopping_dining                              21 occurrences
#   physiotherapy                                21 occurrences
#   lawn_garden                                  20 occurrences
#   aged_care                                    20 occurrences
#   restaurant_business                          20 occurrences
#   online_media                                 20 occurrences
#   online_sales                                 20 occurrences
#   outdoor_education                            20 occurrences
#   casino_hospitality                           20 occurrences
#   national_park                                20 occurrences
#   barber_shop                                  20 occurrences
#   document_management                          20 occurrences
#   refrigeration                                20 occurrences
#   nutrition_coach                              20 occurrences
#   dental_and_medical                           20 occurrences
#   electronic_music                             20 occurrences
#   clean_energy                                 20 occurrences
#   infrastructure                               20 occurrences
#   ski                                          20 occurrences
#   stationary                                   20 occurrences
#   graphic_studio                               20 occurrences
#   college_sports                               20 occurrences
#   cultural_association                         20 occurrences
#   information_security                         20 occurrences
#   party_supply                                 20 occurrences
#   transit                                      20 occurrences
#   biology                                      20 occurrences
#   creative_industry                            20 occurrences
#   child_development                            20 occurrences
#   online_education                             20 occurrences
#   beer_alcohol                                 20 occurrences
#   stomatology                                  20 occurrences
#   minor_league_baseball                        20 occurrences
#   land_management                              20 occurrences
#   monogram                                     19 occurrences
#   community_organization                       19 occurrences
#   event_marketing                              19 occurrences
#   dance_studio                                 19 occurrences
#   hotel_casino                                 19 occurrences
#   talent_agency                                19 occurrences
#   creative_studio                              19 occurrences
#   publications                                 19 occurrences
#   jewerly                                      19 occurrences
#   candle                                       19 occurrences
#   political_campaign                           19 occurrences
#   organisation                                 19 occurrences
#   video_marketing                              19 occurrences
#   family_law                                   19 occurrences
#   environmental_conservation                   19 occurrences
#   design_communications                        19 occurrences
#   design_and_marketing                         19 occurrences
#   institutions_non_profits                     19 occurrences
#   business_solutions                           19 occurrences
#   clothing_line                                19 occurrences
#   author                                       19 occurrences
#   wireless_communication                       19 occurrences
#   lending                                      19 occurrences
#   international                                19 occurrences
#   metal_industry                               19 occurrences
#   wireless_technology                          19 occurrences
#   type                                         19 occurrences
#   mattress                                     19 occurrences
#   typesetting                                  19 occurrences
#   housing_developer                            19 occurrences
#   stationary_designer                          19 occurrences
#   outdoor_apparel                              19 occurrences
#   event_space                                  19 occurrences
#   career_coaching                              19 occurrences
#   political_consulting                         19 occurrences
#   virginia                                     19 occurrences
#   construction_services                        19 occurrences
#   exhibitions                                  19 occurrences
#   bicycle_shop                                 19 occurrences
#   veterinary_medicine                          19 occurrences
#   outdoor_retail                               19 occurrences
#   specialty_coffee                             19 occurrences
#   custom_furniture                             19 occurrences
#   pottery                                      19 occurrences
#   decorating_service                           19 occurrences
#   entertainment_the_arts                       18 occurrences
#   ceramic                                      18 occurrences
#   wellcrafted_brands                           18 occurrences
#   3_tier_auto_financing                        18 occurrences
#   kids_clothing                                18 occurrences
#   music_club                                   18 occurrences
#   apartment_rental                             18 occurrences
#   energy_solutions                             18 occurrences
#   identity                                     18 occurrences
#   art_book                                     18 occurrences
#   knitting                                     18 occurrences
#   wall_entries                                 18 occurrences
#   tv_channel                                   18 occurrences
#   digital_magazines                            18 occurrences
#   casual                                       18 occurrences
#   digital_advertising                          18 occurrences
#   business_software                            18 occurrences
#   heathcare                                    18 occurrences
#   pet_supply                                   18 occurrences
#   mobile_software                              18 occurrences
#   software_developer                           18 occurrences
#   design_and_advertising                       18 occurrences
#   unsold                                       18 occurrences
#   software_manufacture                         18 occurrences
#   housing_and_land_council                     18 occurrences
#   sports_hospitality                           18 occurrences
#   humane_society                               18 occurrences
#   bioscience                                   18 occurrences
#   cargo                                        18 occurrences
#   parenting                                    18 occurrences
#   food_and_entertainment                       18 occurrences
#   business_training                            18 occurrences
#   blogger                                      18 occurrences
#   professional_hockey                          18 occurrences
#   sushi_bar                                    18 occurrences
#   transporation                                18 occurrences
#   business_association                         18 occurrences
#   plants                                       18 occurrences
#   fitness_apparel                              18 occurrences
#   film_music                                   18 occurrences
#   decor                                        18 occurrences
#   investigation                                18 occurrences
#   salt                                         18 occurrences
#   leadership                                   17 occurrences
#   retail_development                           17 occurrences
#   fuel_oil                                     17 occurrences
#   storage_products                             17 occurrences
#   construction_industry                        17 occurrences
#   healthy_food                                 17 occurrences
#   consulting_services                          17 occurrences
#   people                                       17 occurrences
#   stickers                                     17 occurrences
#   music_bands                                  17 occurrences
#   design_community                             17 occurrences
#   air_purification                             17 occurrences
#   automobile_industry                          17 occurrences
#   handicraft                                   17 occurrences
#   school_sports                                17 occurrences
#   auction                                      17 occurrences
#   radio_broadcasting                           17 occurrences
#   it_and_communication                         17 occurrences
#   final                                        17 occurrences
#   yachting                                     17 occurrences
#   multi_media                                  17 occurrences
#   adult                                        17 occurrences
#   printers                                     17 occurrences
#   bicycle_repair                               17 occurrences
#   baby_clothing                                17 occurrences
#   v2                                           17 occurrences
#   television_production                        17 occurrences
#   charity_organization                         17 occurrences
#   iron                                         17 occurrences
#   online_magazine                              17 occurrences
#   pc                                           17 occurrences
#   coffee_roasters                              17 occurrences
#   cruise_line                                  17 occurrences
#   beauty_health                                17 occurrences
#   state_government                             17 occurrences
#   alcoholic_drinks                             17 occurrences
#   christian_school                             17 occurrences
#   tailor                                       17 occurrences
#   artisan                                      17 occurrences
#   literary                                     17 occurrences
#   holistic_healing                             17 occurrences
#   athletic_merchandising                       17 occurrences
#   chemical_industry                            17 occurrences
#   kitchen_and_bath                             17 occurrences
#   religous                                     17 occurrences
#   trading_company                              17 occurrences
#   oil_industry                                 17 occurrences
#   investment_services                          17 occurrences
#   home_developer                               17 occurrences
#   virtual_reality                              17 occurrences
#   trades                                       17 occurrences
#   mechanical_engineering                       17 occurrences
#   professional_basketball                      16 occurrences
#   design_furnishings                           16 occurrences
#   gymnastics                                   16 occurrences
#   fire_safety                                  16 occurrences
#   outdoor_products                             16 occurrences
#   research_institute                           16 occurrences
#   coin_collecting                              16 occurrences
#   paintball                                    16 occurrences
#   party                                        16 occurrences
#   enterprise_software                          16 occurrences
#   human_services                               16 occurrences
#   aquaculture                                  16 occurrences
#   gaming_collectibles                          16 occurrences
#   recruitment_training                         16 occurrences
#   athletic_training                            16 occurrences
#   nfl                                          16 occurrences
#   park                                         16 occurrences
#   data_storage                                 16 occurrences
#   heating_technology                           16 occurrences
#   haulier                                      16 occurrences
#   app_software                                 16 occurrences
#   clothing_fashion                             16 occurrences
#   outdoor_oufitter                             16 occurrences
#   active_lifestyle                             16 occurrences
#   web_app                                      16 occurrences
#   travel_destination                           16 occurrences
#   food_market                                  16 occurrences
#   affordable_housing                           16 occurrences
#   sales_consulting                             16 occurrences
#   musical_group                                16 occurrences
#   textile_industry                             16 occurrences
#   mass_transit                                 16 occurrences
#   turf_equipment                               16 occurrences
#   clothing_and_apparel                         16 occurrences
#   e_learning                                   16 occurrences
#   e_liquid                                     16 occurrences
#   tecnology                                    16 occurrences
#   solar_panels                                 16 occurrences
#   medical_dental                               16 occurrences
#   jewelry_fashion                              16 occurrences
#   call_center                                  16 occurrences
#   printing_press                               16 occurrences
#   political_party                              16 occurrences
#   risk_management                              16 occurrences
#   missions                                     16 occurrences
#   hunting_and_fishing                          16 occurrences
#   skincare_cosmetics                           16 occurrences
#   any                                          16 occurrences
#   vet                                          16 occurrences
#   windows                                      16 occurrences
#   texas_proposed                               16 occurrences
#   crossfit                                     15 occurrences
#   jpg                                          15 occurrences
#   church_institution                           15 occurrences
#   sea_food                                     15 occurrences
#   mediation                                    15 occurrences
#   life_science                                 15 occurrences
#   yoga_school                                  15 occurrences
#   identity_theft_protection                    15 occurrences
#   clothing_industry                            15 occurrences
#   philanthropic                                15 occurrences
#   traveling                                    15 occurrences
#   construction_contracting                     15 occurrences
#   public_art                                   15 occurrences
#   media_communications                         15 occurrences
#   football_team                                15 occurrences
#   beverage_distribution                        15 occurrences
#   edutech                                      15 occurrences
#   fashion_label                                15 occurrences
#   charity_foundation                           15 occurrences
#   motorcycle_festival                          15 occurrences
#   single_letters                               15 occurrences
#   cultural_center                              15 occurrences
#   dental_medical                               15 occurrences
#   outdoor_gear                                 15 occurrences
#   business_support                             15 occurrences
#   libraries                                    15 occurrences
#   sport_recreation                             15 occurrences
#   broadcast_entertainment                      15 occurrences
#   self_storage                                 15 occurrences
#   npo                                          15 occurrences
#   garden_art                                   15 occurrences
#   fine_jewelry                                 15 occurrences
#   llp                                          15 occurrences
#   sports_management                            15 occurrences
#   community_outreach                           15 occurrences
#   surf_shop                                    15 occurrences
#   culture_museums                              15 occurrences
#   health_industry                              15 occurrences
#   marketing_design                             15 occurrences
#   marketing_firm                               15 occurrences
#   retail_consumer                              15 occurrences
#   pa                                           15 occurrences
#   greeting_card                                15 occurrences
#   copy_writing                                 15 occurrences
#   t_shirts                                     15 occurrences
#   pharmaceutical_advertising                   15 occurrences
#   for_fun                                      15 occurrences
#   christian_publishing                         15 occurrences
#   hazardous_materials                          15 occurrences
#   product_development                          15 occurrences
#   audit_firm                                   15 occurrences
#   finacial                                     15 occurrences
#   lab                                          15 occurrences
#   laundry_service                              15 occurrences
#   zoological_society                           15 occurrences
#   symphony_orchestra                           15 occurrences
#   mobile_technology                            15 occurrences
#   public_policy                                15 occurrences
#   stock_market                                 15 occurrences
#   aerosystems                                  15 occurrences
#   wood_working                                 15 occurrences
#   home_development                             14 occurrences
#   art_festival                                 14 occurrences
#   institutions_nonprofits                      14 occurrences
#   dmd                                          14 occurrences
#   support_group                                14 occurrences
#   md                                           14 occurrences
#   design_education                             14 occurrences
#   annuity_insurance                            14 occurrences
#   full                                         14 occurrences
#   economic_and_farming                         14 occurrences
#   medical_pharmaceutical                       14 occurrences
#   industrial_services                          14 occurrences
#   online_stream_television                     14 occurrences
#   handmade_must_haves                          14 occurrences
#   union                                        14 occurrences
#   spring_water                                 14 occurrences
#   paper_goods                                  14 occurrences
#   floral_and_events                            14 occurrences
#   navigation                                   14 occurrences
#   well_being                                   14 occurrences
#   bar_nightclub                                14 occurrences
#   media_audits                                 14 occurrences
#   online_advertising                           14 occurrences
#   food_label_packaging                         14 occurrences
#   health_technology                            14 occurrences
#   artist_management                            14 occurrences
#   aerial_tree_trimming                         14 occurrences
#   lobbying                                     14 occurrences
#   corporation                                  14 occurrences
#   childrens_video_publishing_and_education     14 occurrences
#   large_format_printing                        14 occurrences
#   medical_cannabis                             14 occurrences
# ...
#   gift_wrap                                    11 occurrences
#   ammunition                                   11 occurrences
#   sporting_events                              11 occurrences
#   chamber                                      10 occurrences
#   foundry                                      10 occurrences
#   coolers                                      10 occurrences
#   servicios                                    10 occurrences
#   sports_memorabilia                           10 occurrences
#   public_speaker                               10 occurrences
#   preservation                                 10 occurrences
#   type_foundry                                 10 occurrences
#   apothecary                                   10 occurrences
#   motorcycle_racing                            10 occurrences
#   the_lone_ranger_mechandise_collection        10 occurrences
#   baby_softgoods                               10 occurrences
#   local_economies                              10 occurrences
#   north_carolina                               10 occurrences
#   titanium_fasteners                           10 occurrences
#   civic_pride                                  10 occurrences
#   baby_eye_care                                10 occurrences
#   mobility                                     10 occurrences
#   children_toys                                10 occurrences
#   er                                           10 occurrences
#   fair_organizer                               10 occurrences
#   booking                                      10 occurrences
#   badge                                        10 occurrences
#   investigative_journalism                     10 occurrences
#   motor_racing                                 10 occurrences
#   startups                                     10 occurrences
#   asian_cultural_center                        10 occurrences
#   race                                         10 occurrences
#   fraternity                                   10 occurrences
#   900x900                                      10 occurrences
#   acquisitions                                 10 occurrences
#   3d_graphics                                  10 occurrences
#   entrepreneurship                             10 occurrences
#   medicinal_cannabis                           10 occurrences
#   representative                               10 occurrences
#   laboratory_equipment                         10 occurrences
#   filtration                                   10 occurrences
#   resources                                    10 occurrences
#   asi                                           9 occurrences
#   handmade_crafts                               9 occurrences
#   technical                                     9 occurrences
#   diabetes_awareness                            9 occurrences
#   charitable_investment                         9 occurrences
#   hearing_aids                                  9 occurrences
#   metrology                                     9 occurrences
#   kansas                                        9 occurrences
#   new_zealand                                   9 occurrences
#   motivational                                  9 occurrences
#   air_hygiene                                   9 occurrences
#   lettering                                     9 occurrences
#   engineer                                      9 occurrences
#   anniversary                                   9 occurrences
#   traffic                                       9 occurrences
#   int_ext_design_group                          9 occurrences
#   maps                                          9 occurrences
#   heart_clinic                                  9 occurrences
#   ohio                                          9 occurrences
#   impulse                                       9 occurrences
#   gps                                           9 occurrences
#   bio                                           9 occurrences
#   entertaining                                  9 occurrences
#   sign                                          9 occurrences
#   interior_studio                               9 occurrences
#   sale                                          9 occurrences
#   business_network                              9 occurrences
#   tailoring                                     9 occurrences
#   type_design                                   9 occurrences
#   baby_sleepwear                                9 occurrences
#   white_and_black                               9 occurrences
#   reward_program                                9 occurrences
#   professional_associations                     9 occurrences
#   bike_storage                                  9 occurrences
#   scrapbooking                                  9 occurrences
#   or                                            9 occurrences
#   sports_entertaintment                         9 occurrences
#   territorial_branding                          9 occurrences
#   book_club                                     8 occurrences
#   roll_core_remanufacturing                     8 occurrences
#   dating_app                                    8 occurrences
#   creativity                                    8 occurrences
#   transcription                                 8 occurrences
#   translation_services                          8 occurrences
#   conglomerates                                 8 occurrences
#   newsletter                                    8 occurrences
#   businessmen                                   8 occurrences
#   information_portal                            8 occurrences
#   women_of_action                               8 occurrences
#   design_association                            8 occurrences
#   wildlife_conservation                         8 occurrences
#   imaging                                       8 occurrences
#   genealogy                                     8 occurrences
#   resource_asset_management                     8 occurrences
#   allied                                        8 occurrences
#   productivity                                  8 occurrences
#   neon                                          8 occurrences
#   luxury_eyewear_retailer                       8 occurrences
#   direct_market                                 8 occurrences
#   mailing                                       8 occurrences
#   neuroscience                                  8 occurrences
#   geographic_information_services               8 occurrences
#   corporate_service                             8 occurrences
#   trumpet_manufactory                           8 occurrences
#   peace                                         8 occurrences
#   cash_back_loyalty_program                     8 occurrences
#   measuring_instruments                         8 occurrences
#   australia                                     8 occurrences
#   postal_service                                8 occurrences
#   restauration                                  8 occurrences
#   sleep                                         8 occurrences
#   eyeglasses                                    8 occurrences
#   therapeutic_riding_center                     8 occurrences
#   p                                             8 occurrences
#   reunion                                       8 occurrences
#   incentive                                     8 occurrences
#   postal                                        8 occurrences
#   shield                                        8 occurrences
#   natural_science                               8 occurrences
#   nine_regions_of_washington                    8 occurrences
#   industrial_supplier                           8 occurrences
#   light_fixture_manufacturer                    8 occurrences
#   enterainment                                  8 occurrences
#   formation                                     8 occurrences
#   powersports                                   8 occurrences
#   phone_application                             8 occurrences
#   collectible_toys                              7 occurrences
#   heath                                         7 occurrences
#   archeology                                    7 occurrences
#   trust                                         7 occurrences
#   non_food                                      7 occurrences
#   contest                                       7 occurrences
#   canabis                                       7 occurrences
#   cookery                                       7 occurrences
#   merch                                         7 occurrences
#   electrics                                     7 occurrences
#   talent                                        7 occurrences
#   support                                       7 occurrences
#   galeria_de_comunicacion                       7 occurrences
#   compost                                       7 occurrences
#   industrial_honing                             7 occurrences
#   solutions                                     7 occurrences
#   private_club                                  7 occurrences
#   planning                                      7 occurrences
#   digital_audio_networking_products             7 occurrences
#   license_goods                                 7 occurrences
#   worlds_fair_stand                             7 occurrences
#   show                                          7 occurrences
#   timeshare                                     7 occurrences
#   fertility                                     7 occurrences
#   led_lighting                                  7 occurrences
#   historical                                    7 occurrences
#   information_services                          7 occurrences
#   recreational_dance                            7 occurrences
#   legacy_company                                7 occurrences
#   handmade_products                             7 occurrences
#   physics                                       7 occurrences
#   adoption_agency                               7 occurrences
#   thomson                                       7 occurrences
#   collector_toys                                7 occurrences
#   happiness                                     7 occurrences
#   souvenirs                                     7 occurrences
#   caregivers                                    7 occurrences
#   craftsman                                     7 occurrences
#   energetics                                    7 occurrences
#   odor_science                                  7 occurrences
#   chess                                         7 occurrences
#   sports_sporting_wear                          7 occurrences
#   crowdsourcing                                 7 occurrences
#   flowers_shop                                  7 occurrences
#   russia                                        7 occurrences
#   managment                                     7 occurrences
#   mythology                                     7 occurrences
#   awareness                                     7 occurrences
#   all_things_paper                              6 occurrences
#   internet_filing                               6 occurrences
#   handmade_gifts                                6 occurrences
#   chicago                                       6 occurrences
#   change_management                             6 occurrences
#   handmade_soaps                                6 occurrences
#   inspirational                                 6 occurrences
#   gifting_services                              6 occurrences
#   cartography                                   6 occurrences
#   trade_union                                   6 occurrences
#   astrology_space_research                      6 occurrences
#   cheerleading                                  6 occurrences
#   b_to_c                                        6 occurrences
#   paining_and_decorating                        6 occurrences
#   mode                                          6 occurrences
#   bladesmith                                    6 occurrences
#   tustin                                        6 occurrences
#   culture_change                                6 occurrences
#   breast_cancer_awareness_tennis                6 occurrences
#   precison_medical_fluids                       6 occurrences
#   entertainmemt                                 6 occurrences
#   merges_and_absorption                         6 occurrences
#   picture_framing                               6 occurrences
#   unmanned_land_surveying_using_drones          6 occurrences
#   auctions                                      6 occurrences
#   repellents                                    6 occurrences
#   golfball_manufacturing                        6 occurrences
#   train                                         6 occurrences
#   contemporary_dance                            6 occurrences
#   liscensing                                    6 occurrences
#   entertaintment                                6 occurrences
#   relaxation                                    6 occurrences
#   celebrity                                     6 occurrences
#   warehouse                                     6 occurrences
#   automoto                                      6 occurrences
#   science_and_research                          6 occurrences
#   toolmaking                                    6 occurrences
#   augmented_reality                             6 occurrences
#   stained_glass                                 6 occurrences
#   writing_kit_for_grandparents_and_grandchildren      6 occurrences
#   achaar_shop                                   6 occurrences
#   hardware_and_bricolage                        6 occurrences
#   framing                                       6 occurrences
#   regional                                      6 occurrences
#   rifles                                        6 occurrences
#   lobbyist                                      6 occurrences
#   discount_service                              6 occurrences
#   startup_accelerator                           6 occurrences
#   premium_goods                                 6 occurrences
#   showchoir                                     6 occurrences
#   mapping                                       6 occurrences
#   toy_company                                   6 occurrences
#   air_filtration                                6 occurrences
#   photonics                                     6 occurrences
#   sofia                                         6 occurrences
#   identity_development                          6 occurrences
#   installation                                  6 occurrences
#   magnetic_technology                           6 occurrences
#   retirement_industry                           6 occurrences
#   usa                                           6 occurrences
#   turf_installer                                6 occurrences
#   reality                                       6 occurrences
#   retail_sunglasses                             6 occurrences
#   performance_arts                              6 occurrences
#   hobby_shop                                    6 occurrences
#   munich                                        6 occurrences
#   servicio                                      6 occurrences
#   direct_sales                                  6 occurrences
#   collections                                   6 occurrences
#   elderly_care                                  6 occurrences
#   labs                                          6 occurrences
#   sociology                                     6 occurrences
#   candy_store                                   6 occurrences
#   emergency_ems                                 6 occurrences
#   product_line                                  6 occurrences
#   tech_saas                                     6 occurrences
#   humanity                                      6 occurrences
#   resiliency                                    6 occurrences
#   networking_business                           6 occurrences
#   competitive_eating                            6 occurrences
#   corporate_a_v_installation                    6 occurrences
#
# Total logos that will get original category added to tags: 42,741

# %%
# Create a copy for processing
df_processed = df.copy()

print("Processing categories and tags...")

# Ensure tags column exists
if 'tags' not in df_processed.columns:
    df_processed['tags'] = ''
    print("Created empty tags column")

# Statistics tracking
stats = {
    'total_processed': 0,
    'kept_valid': 0,
    'changed_to_unclassified': 0,
    'added_to_tags': 0,
    'na_categories': 0
}

def process_row(row):
    """Process a single row to update category and tags"""
    stats['total_processed'] += 1
    
    original_category = row['category']
    
    # Handle NA categories
    if pd.isna(original_category):
        stats['na_categories'] += 1
        return row
    
    original_category_str = str(original_category)
    
    # Check if category is valid (in consolidation_map)
    if original_category_str in valid_categories:
        # Keep the valid category
        stats['kept_valid'] += 1
        return row
    else:
        # Change to unclassified
        stats['changed_to_unclassified'] += 1
        row['category'] = 'unclassified'
        
        # If it's a frequent category, add to tags
        if original_category_str in frequent_unclassified_set:
            stats['added_to_tags'] += 1
            
            # Get current tags
            current_tags = row.get('tags', '')
            if pd.isna(current_tags):
                current_tags = ''
            
            # Parse existing tags
            existing_tags = [tag.strip() for tag in str(current_tags).split(',') if tag.strip()]
            
            # Add original category if not already present
            if original_category_str not in existing_tags:
                existing_tags.append(original_category_str)
                row['tags'] = ', '.join(existing_tags)
        
        return row

# Apply processing to each row
print("Applying category and tag updates...")
df_processed = df_processed.apply(process_row, axis=1)

print(f"\n=== PROCESSING STATISTICS ===")
print(f"Total rows processed: {stats['total_processed']:,}")
print(f"Categories kept (valid): {stats['kept_valid']:,}")
print(f"Categories changed to 'unclassified': {stats['changed_to_unclassified']:,}")
print(f"Original categories added to tags: {stats['added_to_tags']:,}")
print(f"NA categories preserved: {stats['na_categories']:,}")
# Out:
# Processing categories and tags...
# Applying category and tag updates...
#
# === PROCESSING STATISTICS ===
# Total rows processed: 352,154
# Categories kept (valid): 307,642
# Categories changed to 'unclassified': 44,512
# Original categories added to tags: 42,741
# NA categories preserved: 0

# %%
# Analyze the results
print("\n=== FINAL CATEGORY ANALYSIS ===")
final_category_counts = df_processed['category'].value_counts()
print(f"Final unique categories: {df_processed['category'].nunique()}")
print(f"\nFinal category distribution:")
for i, (cat, count) in enumerate(final_category_counts.items(), 1):
    percentage = (count / len(df_processed)) * 100
    print(f"{i:2d}. {cat:<30} {count:>7} ({percentage:>5.2f}%)")

# Check tags analysis
print(f"\n=== TAGS ANALYSIS ===")
rows_with_tags = df_processed['tags'].notna() & (df_processed['tags'] != '')
print(f"Rows with non-empty tags: {rows_with_tags.sum():,} ({(rows_with_tags.sum() / len(df_processed)) * 100:.2f}%)")

# Show some examples of rows that got tags added
print(f"\nSample rows with added tags (from frequent unclassified categories):")
sample_tagged = df_processed[df_processed['category'] == 'unclassified'][['category', 'tags']].head(10)
for i, (idx, row) in enumerate(sample_tagged.iterrows(), 1):
    if row['tags']:
        print(f"{i:2d}. Tags: {row['tags'][:80]}{'...' if len(str(row['tags'])) > 80 else ''}")

# Verify all categories are now valid
final_categories = set(df_processed['category'].dropna().astype(str))
invalid_final = final_categories - valid_categories - {'unclassified'}
print(f"\nInvalid categories remaining (should be 0): {len(invalid_final)}")
if invalid_final:
    print(f"WARNING: Still have invalid categories: {invalid_final}")
# Out:
# === FINAL CATEGORY ANALYSIS ===
# Final unique categories: 109
#
# Final category distribution:
#  1. unclassified                     73954 (21.00%)
#  2. sports_recreation                11383 ( 3.23%)
#  3. restaurant_dining                10963 ( 3.11%)
#  4. real_estate_residential          10825 ( 3.07%)
#  5. healthcare_general               10534 ( 2.99%)
#  6. design_creative                  10366 ( 2.94%)
#  7. nonprofit_charity                10134 ( 2.88%)
#  8. fashion_apparel                   9174 ( 2.61%)
#  9. education_k12                     8572 ( 2.43%)
# 10. music_industry                    7318 ( 2.08%)
# 11. marketing_advertising             6806 ( 1.93%)
# 12. retail_general                    6503 ( 1.85%)
# 13. home_improvement                  6200 ( 1.76%)
# 14. entertainment_venues              6089 ( 1.73%)
# 15. chemical_materials                5501 ( 1.56%)
# 16. web_digital                       5470 ( 1.55%)
# 17. arts_culture                      5195 ( 1.48%)
# 18. food_production                   5161 ( 1.47%)
# 19. photography_video                 4720 ( 1.34%)
# 20. financial_services                4645 ( 1.32%)
# 21. travel_tourism                    4609 ( 1.31%)
# 22. hotels_lodging                    4602 ( 1.31%)
# 23. wellness_fitness                  4261 ( 1.21%)
# 24. brewery_alcohol                   4233 ( 1.20%)
# 25. religious_faith                   4001 ( 1.14%)
# 26. software_development              3926 ( 1.11%)
# 27. beverage_general                  3916 ( 1.11%)
# 28. printing_publishing               3787 ( 1.08%)
# 29. personal_professional             3763 ( 1.07%)
# 30. it_services                       3307 ( 0.94%)
# 31. legal_services                    3289 ( 0.93%)
# 32. film_video                        3077 ( 0.87%)
# 33. cafe_coffee                       2911 ( 0.83%)
# 34. medical_specialty                 2571 ( 0.73%)
# 35. government_public                 2425 ( 0.69%)
# 36. media_publishing                  2408 ( 0.68%)
# 37. catering_events                   2268 ( 0.64%)
# 38. salon_spa                         2256 ( 0.64%)
# 39. insurance_services                2207 ( 0.63%)
# 40. automotive_transport              2201 ( 0.63%)
# 41. home_goods                        2173 ( 0.62%)
# 42. telecommunications                2150 ( 0.61%)
# 43. real_estate_development           2142 ( 0.61%)
# 44. gaming_entertainment              2076 ( 0.59%)
# 45. other_services                    2047 ( 0.58%)
# 46. energy_utilities                  2000 ( 0.57%)
# 47. hospitality_services              1917 ( 0.54%)
# 48. transportation_services           1859 ( 0.53%)
# 49. vacation_recreation               1674 ( 0.48%)
# 50. textiles_manufacturing            1670 ( 0.47%)
# 51. jewelry_accessories               1527 ( 0.43%)
# 52. beauty_cosmetics                  1511 ( 0.43%)
# 53. dental_services                   1466 ( 0.42%)
# 54. construction_general              1441 ( 0.41%)
# 55. environmental_services            1430 ( 0.41%)
# 56. construction_specialty            1412 ( 0.40%)
# 57. manufacturing_general             1411 ( 0.40%)
# 58. sports_teams                      1301 ( 0.37%)
# 59. community_social                  1261 ( 0.36%)
# 60. real_estate_commercial            1244 ( 0.35%)
# 61. landscaping_garden                1201 ( 0.34%)
# 62. human_resources                   1148 ( 0.33%)
# 63. childcare_youth                   1145 ( 0.33%)
# 64. consulting_business               1127 ( 0.32%)
# 65. fintech_crypto                    1112 ( 0.32%)
# 66. property_management               1109 ( 0.31%)
# 67. educational_services              1098 ( 0.31%)
# 68. radio_podcast                     1057 ( 0.30%)
# 69. training_development              1048 ( 0.30%)
# 70. higher_education                  1043 ( 0.30%)
# 71. veterinary                        1006 ( 0.29%)
# 72. home_services                      997 ( 0.28%)
# 73. security_safety                    948 ( 0.27%)
# 74. pet_services                       942 ( 0.27%)
# 75. ecommerce_online                   934 ( 0.27%)
# 76. wholesale_distribution             907 ( 0.26%)
# 77. skateboarding_action               891 ( 0.25%)
# 78. lifestyle_personal                 877 ( 0.25%)
# 79. event_services                     875 ( 0.25%)
# 80. grocery_retail                     871 ( 0.25%)
# 81. outdoor_sports                     850 ( 0.24%)
# 82. tech_hardware                      838 ( 0.24%)
# 83. mental_health                      749 ( 0.21%)
# 84. animal_services                    744 ( 0.21%)
# 85. aviation_services                  734 ( 0.21%)
# 86. accounting_tax                     661 ( 0.19%)
# 87. agriculture_farming                637 ( 0.18%)
# 88. construction_materials             627 ( 0.18%)
# 89. construction_home                  573 ( 0.16%)
# 90. water_services                     550 ( 0.16%)
# 91. bar_nightlife                      495 ( 0.14%)
# 92. forestry_lumber                    489 ( 0.14%)
# 93. footwear_leather                   482 ( 0.14%)
# 94. vehicle_sales                      425 ( 0.12%)
# 95. auto_services                      392 ( 0.11%)
# 96. health_wellness                    346 ( 0.10%)
# 97. mining_extraction                  342 ( 0.10%)
# 98. marine_services                    320 ( 0.09%)
# 99. gambling_betting                   304 ( 0.09%)
# 100. data_analytics                     296 ( 0.08%)
# 101. cleaning_maintenance               265 ( 0.08%)
# 102. tobacco_vaping                     253 ( 0.07%)
# 103. martial_arts                       237 ( 0.07%)
# 104. aerospace_defense                  229 ( 0.07%)
# 105. fitness_health                     217 ( 0.06%)
# 106. funeral_services                   182 ( 0.05%)
# 107. tattoo_body_art                    177 ( 0.05%)
# 108. import_export                      145 ( 0.04%)
# 109. tattoo body_art                     16 ( 0.00%)
#
# === TAGS ANALYSIS ===
# Rows with non-empty tags: 352,154 (100.00%)
#
# Sample rows with added tags (from frequent unclassified categories):
#  1. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  2. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  3. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  4. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  5. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  6. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  7. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  8. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#  9. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
# 10. Tags: successful_vibe, minimalist, thoughtprovoking, abstract, recognizable, relatable...
#
# Invalid categories remaining (should be 0): 0

# %%
# Save the processed metadata
print(f"\nSaving processed metadata to {output_metadata_csv}...")
df_processed.to_csv(output_metadata_csv, index=False)
print(f"Successfully saved metadata9.csv!")

print(f"\n=== FINAL SUMMARY ===")
print(f"Input file: {input_metadata_csv}")
print(f"Output file: {output_metadata_csv}")
print(f"Total logos: {len(df_processed):,}")
print(f"Valid categories in consolidation_map: {len(valid_categories)}")
print(f"Final unique categories: {df_processed['category'].nunique()}")
print(f"Categories changed to 'unclassified': {stats['changed_to_unclassified']:,}")
print(f"Frequent unclassified categories added to tags: {len(frequent_unclassified)}")
print(f"Logos with tags added: {stats['added_to_tags']:,}")
print(f"Rows with non-empty tags: {rows_with_tags.sum():,}")

# Show the frequency threshold used
print(f"\nFrequency threshold for adding to tags: >5 occurrences")
print(f"Categories above threshold: {len(frequent_unclassified)}")
if frequent_unclassified:
    min_freq = min(count for _, count in frequent_unclassified)
    max_freq = max(count for _, count in frequent_unclassified)
    print(f"Range of frequencies added to tags: {min_freq} - {max_freq}")
# Out:
# Saving processed metadata to ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata9.csv...
# Successfully saved metadata9.csv!
#
# === FINAL SUMMARY ===
# Input file: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata8.csv
# Output file: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata9.csv
# Total logos: 352,154
# Valid categories in consolidation_map: 109
# Final unique categories: 109
# Categories changed to 'unclassified': 44,512
# Frequent unclassified categories added to tags: 1101
# Logos with tags added: 42,741
# Rows with non-empty tags: 352,154
#
# Frequency threshold for adding to tags: >5 occurrences
# Categories above threshold: 1101
# Range of frequencies added to tags: 6 - 7866
