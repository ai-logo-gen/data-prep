# %% [markdown]
# # Amazing Logos V4 - Step 4: Categories Embedding Preparation
#
# This notebook prepares embeddings for category matching using OpenAI's text embedding model.
#
# ## Configuration:
# - **Boolean flags** control which embeddings to compute:
#   - `COMPUTE_CONSOLIDATION_EMBEDDINGS`: Set to `True` to compute embeddings for consolidation map keys
#   - `COMPUTE_CATEGORY_EMBEDDINGS`: Set to `True` to compute embeddings for unique categories
#
# ## Steps:
# 1. **Consolidation Map Embeddings** (optional): Compute embeddings for all keys in `consolidation_map` using OpenAI's `text-embedding-3-large` model
# 2. **Unique Category Embeddings**: Read metadata CSV and compute embeddings for each unique category (excluding 'unclassified')
# 3. **Save Results**:
#    - Save consolidation map embeddings to JSON (if computed)
#    - Save unique category embeddings to JSON (if computed)
#
# ## Outputs:
# - `consolidation_map_embeddings.json`: Embeddings for consolidation map keys (optional)
# - `unique_category_embeddings.json`: Embeddings for unique categories only (not per logo row)
#
# ## Next Step:
# In a subsequent notebook, these embeddings will be used to:
# - Load both embedding JSON files
# - Compute cosine similarity between each unique category and consolidation map keys
# - Create a mapping from current categories to target categories based on highest similarity
# - Apply this mapping to update the metadata
#
# **Note**: Make sure to set your OpenAI API key as environment variable `OPENAI_API_KEY` before running this notebook.

# %%
import pandas as pd
from pathlib import Path
import sys

# Add utils folder to path
utils_path = Path('../../utils')
sys.path.append(str(utils_path))

# Import consolidation functions
from consolidation import consolidation_map

# %%
import openai
import json
import time
from openai import OpenAI

# Initialize OpenAI client (make sure to set your API key)
# You can set it as environment variable: OPENAI_API_KEY
client = OpenAI()

# Paths
input_metadata_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata7.csv')
output_consolidation_embeddings = Path('../output/amazing_logos_v4/data/consolidation_map_embeddings.json')
output_category_embeddings = Path('../output/amazing_logos_v4/data/category_embeddings.csv')

print(f"Input metadata CSV: {input_metadata_csv}")
print(f"Output consolidation embeddings: {output_consolidation_embeddings}")
print(f"Output category embeddings: {output_category_embeddings}")

# Check if input file exists
if not input_metadata_csv.exists():
    print(f"ERROR: Input file {input_metadata_csv} does not exist!")
else:
    print(f"Input metadata file exists.")

print(f"Found {len(consolidation_map)} categories in consolidation_map")
# Out:
# Input metadata CSV: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata7.csv
# Output consolidation embeddings: ..\output\amazing_logos_v4\data\consolidation_map_embeddings.json
# Output category embeddings: ..\output\amazing_logos_v4\data\category_embeddings.csv
# Input metadata file exists.
# Found 108 categories in consolidation_map

# %%
def get_embedding(text, model="text-embedding-3-large", max_retries=3, delay=1):
    """
    Get embedding for a text using OpenAI's embedding model.
    
    Args:
        text (str): Text to embed
        model (str): OpenAI embedding model to use
        max_retries (int): Maximum number of retries on failure
        delay (float): Delay between retries in seconds
    
    Returns:
        list: Embedding vector
    """
    for attempt in range(max_retries):
        try:
            # Clean and prepare text
            text = str(text).strip()
            if not text:
                print(f"Warning: Empty text provided")
                return None
                
            response = client.embeddings.create(
                input=text,
                model=model
            )
            return response.data[0].embedding
        
        except Exception as e:
            print(f"Attempt {attempt + 1} failed for text '{text[:50]}...': {e}")
            if attempt < max_retries - 1:
                time.sleep(delay * (2 ** attempt))  # Exponential backoff
            else:
                print(f"Failed to get embedding after {max_retries} attempts")
                return None

# Configuration flags to control which embeddings to compute
COMPUTE_CONSOLIDATION_EMBEDDINGS = False  # Set to True if you want to compute consolidation map embeddings
COMPUTE_CATEGORY_EMBEDDINGS = True        # Set to True if you want to compute category embeddings

print("Embedding function defined successfully")
print(f"Configuration:")
print(f"  - Compute consolidation map embeddings: {COMPUTE_CONSOLIDATION_EMBEDDINGS}")
print(f"  - Compute category embeddings: {COMPUTE_CATEGORY_EMBEDDINGS}")
# Out:
# Embedding function defined successfully
# Configuration:
#   - Compute consolidation map embeddings: False
#   - Compute category embeddings: True

# %%
# Step 1: Compute embeddings for the keys of consolidation_map
print("\n=== Step 1: Computing embeddings for consolidation_map keys ===")

consolidation_embeddings = {}

if COMPUTE_CONSOLIDATION_EMBEDDINGS:
    total_keys = len(consolidation_map)

    for i, (key, synonyms) in enumerate(consolidation_map.items(), 1):
        print(f"Processing {i}/{total_keys}: {key}")
        # Compute embed by creating a combined string in format "Category: <key>, Synonyms: <synonyms>"
        combined_text = f"Category: {key}, Synonyms: {', '.join(synonyms)}"
        embedding = get_embedding(combined_text)

        if embedding is not None:
            consolidation_embeddings[key] = embedding
            print(f"  ✓ Embedded successfully (dim: {len(embedding)})")
        else:
            print(f"  ✗ Failed to embed")
        
        # Small delay to avoid rate limits
        time.sleep(0.1)

    print(f"\nSuccessfully computed {len(consolidation_embeddings)} embeddings out of {total_keys} keys")

    # Save consolidation embeddings to JSON file
    print(f"\nSaving consolidation embeddings to {output_consolidation_embeddings}")
    with open(output_consolidation_embeddings, 'w') as f:
        json.dump(consolidation_embeddings, f, indent=2)
    print("Consolidation embeddings saved successfully")
else:
    print("Skipping consolidation map embeddings (COMPUTE_CONSOLIDATION_EMBEDDINGS = False)")
    # Try to load existing embeddings if available
    if output_consolidation_embeddings.exists():
        print(f"Loading existing consolidation embeddings from {output_consolidation_embeddings}")
        with open(output_consolidation_embeddings, 'r') as f:
            consolidation_embeddings = json.load(f)
        print(f"Loaded {len(consolidation_embeddings)} existing consolidation embeddings")
    else:
        print("No existing consolidation embeddings found")
# Out:
# === Step 1: Computing embeddings for consolidation_map keys ===
# Skipping consolidation map embeddings (COMPUTE_CONSOLIDATION_EMBEDDINGS = False)
# Loading existing consolidation embeddings from ..\output\amazing_logos_v4\data\consolidation_map_embeddings.json
# Loaded 108 existing consolidation embeddings

# %%
# Step 2: Read metadata and compute embeddings for unique categories only
print("\n=== Step 2: Computing embeddings for unique categories ===")

category_embeddings = {}
output_unique_category_embeddings = Path('../output/amazing_logos_v4/data/unique_category_embeddings.json')

if COMPUTE_CATEGORY_EMBEDDINGS:
    # Read metadata
    print("Loading metadata CSV...")
    df_metadata = pd.read_csv(input_metadata_csv)
    print(f"Loaded {len(df_metadata):,} rows")
    print(f"Columns: {list(df_metadata.columns)}")

    # Get unique categories (excluding 'unclassified')
    unique_categories = df_metadata[df_metadata['category'] != 'unclassified']['category'].unique()
    print(f"Found {len(unique_categories)} unique categories (excluding 'unclassified')")

    # Show some examples
    print(f"Example categories: {list(unique_categories[:10])}")

    # Compute embeddings for each unique category
    total_categories = len(unique_categories)

    for i, category in enumerate(unique_categories, 1):
        print(f"Processing {i}/{total_categories}: {category}")
        
        embedding = get_embedding(category)
        
        if embedding is not None:
            category_embeddings[category] = embedding
            print(f"  ✓ Embedded successfully (dim: {len(embedding)})")
        else:
            print(f"  ✗ Failed to embed")
        
        # Small delay to avoid rate limits
        time.sleep(0.1)

    print(f"\nSuccessfully computed {len(category_embeddings)} category embeddings out of {total_categories} categories")
    
    # Save unique category embeddings to JSON file
    print(f"\nSaving unique category embeddings to {output_unique_category_embeddings}")
    with open(output_unique_category_embeddings, 'w') as f:
        json.dump(category_embeddings, f, indent=2)
    print("Unique category embeddings saved successfully")
    
else:
    print("Skipping category embeddings (COMPUTE_CATEGORY_EMBEDDINGS = False)")
    # Try to load existing embeddings if available
    if output_unique_category_embeddings.exists():
        print(f"Loading existing category embeddings from {output_unique_category_embeddings}")
        with open(output_unique_category_embeddings, 'r') as f:
            category_embeddings = json.load(f)
        print(f"Loaded {len(category_embeddings)} existing category embeddings")
    else:
        print("No existing category embeddings found")
# Out:
# === Step 2: Computing embeddings for unique categories ===
# Loading metadata CSV...
# Loaded 393,298 rows
# Columns: ['id', 'company', 'description', 'category', 'tags']
# Found 40499 unique categories (excluding 'unclassified')
# Example categories: ['hospitality_services', 'chemical_materials', 'safty_glass', 'park', 'film_video', 'engineering', 'marketing_advertising', 'design_creative', 'jewelry_accessories', 'vacation_recreation']
# Processing 1/40499: hospitality_services
# Loaded 393,298 rows
# Columns: ['id', 'company', 'description', 'category', 'tags']
# Found 40499 unique categories (excluding 'unclassified')
# Example categories: ['hospitality_services', 'chemical_materials', 'safty_glass', 'park', 'film_video', 'engineering', 'marketing_advertising', 'design_creative', 'jewelry_accessories', 'vacation_recreation']
# Processing 1/40499: hospitality_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 2/40499: chemical_materials
#   ✓ Embedded successfully (dim: 3072)
# Processing 2/40499: chemical_materials
#   ✓ Embedded successfully (dim: 3072)
# Processing 3/40499: safty_glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 3/40499: safty_glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 4/40499: park
#   ✓ Embedded successfully (dim: 3072)
# Processing 4/40499: park
#   ✓ Embedded successfully (dim: 3072)
# Processing 5/40499: film_video
#   ✓ Embedded successfully (dim: 3072)
# Processing 5/40499: film_video
#   ✓ Embedded successfully (dim: 3072)
# Processing 6/40499: engineering
#   ✓ Embedded successfully (dim: 3072)
# Processing 6/40499: engineering
#   ✓ Embedded successfully (dim: 3072)
# Processing 7/40499: marketing_advertising
#   ✓ Embedded successfully (dim: 3072)
# Processing 7/40499: marketing_advertising
#   ✓ Embedded successfully (dim: 3072)
# Processing 8/40499: design_creative
#   ✓ Embedded successfully (dim: 3072)
# Processing 8/40499: design_creative
#   ✓ Embedded successfully (dim: 3072)
# Processing 9/40499: jewelry_accessories
#   ✓ Embedded successfully (dim: 3072)
# Processing 9/40499: jewelry_accessories
#   ✓ Embedded successfully (dim: 3072)
# Processing 10/40499: vacation_recreation
#   ✓ Embedded successfully (dim: 3072)
# Processing 10/40499: vacation_recreation
#   ✓ Embedded successfully (dim: 3072)
# Processing 11/40499: printing_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 11/40499: printing_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 12/40499: haulier
#   ✓ Embedded successfully (dim: 3072)
# Processing 12/40499: haulier
#   ✓ Embedded successfully (dim: 3072)
# Processing 13/40499: arts_culture
#   ✓ Embedded successfully (dim: 3072)
# Processing 13/40499: arts_culture
#   ✓ Embedded successfully (dim: 3072)
# Processing 14/40499: office_supplies
#   ✓ Embedded successfully (dim: 3072)
# Processing 14/40499: office_supplies
#   ✓ Embedded successfully (dim: 3072)
# Processing 15/40499: healthcare_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 15/40499: healthcare_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 16/40499: dental_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 16/40499: dental_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 17/40499: michael_baviera
#   ✓ Embedded successfully (dim: 3072)
# Processing 17/40499: michael_baviera
#   ✓ Embedded successfully (dim: 3072)
# Processing 18/40499: fish_tavern
#   ✓ Embedded successfully (dim: 3072)
# Processing 18/40499: fish_tavern
#   ✓ Embedded successfully (dim: 3072)
# Processing 19/40499: educational_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 19/40499: educational_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 20/40499: insurance_law_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 20/40499: insurance_law_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 21/40499: higher_education
#   ✓ Embedded successfully (dim: 3072)
# Processing 21/40499: higher_education
#   ✓ Embedded successfully (dim: 3072)
# Processing 22/40499: insurance_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 22/40499: insurance_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 23/40499: bank
#   ✓ Embedded successfully (dim: 3072)
# Processing 23/40499: bank
#   ✓ Embedded successfully (dim: 3072)
# Processing 24/40499: petrolium
#   ✓ Embedded successfully (dim: 3072)
# Processing 24/40499: petrolium
#   ✓ Embedded successfully (dim: 3072)
# Processing 25/40499: paper
#   ✓ Embedded successfully (dim: 3072)
# Processing 25/40499: paper
#   ✓ Embedded successfully (dim: 3072)
# Processing 26/40499: helmet_manufacturer
#   ✓ Embedded successfully (dim: 3072)
# Processing 26/40499: helmet_manufacturer
#   ✓ Embedded successfully (dim: 3072)
# Processing 27/40499: fashion_apparel
#   ✓ Embedded successfully (dim: 3072)
# Processing 27/40499: fashion_apparel
#   ✓ Embedded successfully (dim: 3072)
# Processing 28/40499: education_k12
#   ✓ Embedded successfully (dim: 3072)
# Processing 28/40499: education_k12
#   ✓ Embedded successfully (dim: 3072)
# Processing 29/40499: cultural_space
#   ✓ Embedded successfully (dim: 3072)
# Processing 29/40499: cultural_space
#   ✓ Embedded successfully (dim: 3072)
# Processing 30/40499: optical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 30/40499: optical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 31/40499: tourist_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 31/40499: tourist_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 32/40499: financial_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 32/40499: financial_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 33/40499: construction_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 33/40499: construction_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 34/40499: catering_events
#   ✓ Embedded successfully (dim: 3072)
# Processing 34/40499: catering_events
#   ✓ Embedded successfully (dim: 3072)
# Processing 35/40499: brewery_alcohol
#   ✓ Embedded successfully (dim: 3072)
# Processing 35/40499: brewery_alcohol
#   ✓ Embedded successfully (dim: 3072)
# Processing 36/40499: real_estate_residential
#   ✓ Embedded successfully (dim: 3072)
# Processing 36/40499: real_estate_residential
#   ✓ Embedded successfully (dim: 3072)
# Processing 37/40499: studio_boggeri
#   ✓ Embedded successfully (dim: 3072)
# Processing 37/40499: studio_boggeri
#   ✓ Embedded successfully (dim: 3072)
# Processing 38/40499: music_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 38/40499: music_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 39/40499: arts_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 39/40499: arts_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 40/40499: tech_hardware
#   ✓ Embedded successfully (dim: 3072)
# Processing 40/40499: tech_hardware
#   ✓ Embedded successfully (dim: 3072)
# Processing 41/40499: textiles_manufacturing
#   ✓ Embedded successfully (dim: 3072)
# Processing 41/40499: textiles_manufacturing
#   ✓ Embedded successfully (dim: 3072)
# Processing 42/40499: home_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 42/40499: home_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 43/40499: raincoats
#   ✓ Embedded successfully (dim: 3072)
# Processing 43/40499: raincoats
#   ✓ Embedded successfully (dim: 3072)
# Processing 44/40499: event_space
#   ✓ Embedded successfully (dim: 3072)
# Processing 44/40499: event_space
#   ✓ Embedded successfully (dim: 3072)
# Processing 45/40499: it_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 45/40499: it_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 46/40499: medical_visual_training_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 46/40499: medical_visual_training_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 47/40499: marine_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 47/40499: marine_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 48/40499: foods
#   ✓ Embedded successfully (dim: 3072)
# Processing 48/40499: foods
#   ✓ Embedded successfully (dim: 3072)
# Processing 49/40499: silk_quality_mark
#   ✓ Embedded successfully (dim: 3072)
# Processing 49/40499: silk_quality_mark
#   ✓ Embedded successfully (dim: 3072)
# Processing 50/40499: telecommunications
#   ✓ Embedded successfully (dim: 3072)
# Processing 50/40499: telecommunications
#   ✓ Embedded successfully (dim: 3072)
# Processing 51/40499: medical_specialty
#   ✓ Embedded successfully (dim: 3072)
# Processing 51/40499: medical_specialty
#   ✓ Embedded successfully (dim: 3072)
# Processing 52/40499: chruch
#   ✓ Embedded successfully (dim: 3072)
# Processing 52/40499: chruch
#   ✓ Embedded successfully (dim: 3072)
# Processing 53/40499: road_constuction
#   ✓ Embedded successfully (dim: 3072)
# Processing 53/40499: road_constuction
#   ✓ Embedded successfully (dim: 3072)
# Processing 54/40499: air_freight
#   ✓ Embedded successfully (dim: 3072)
# Processing 54/40499: air_freight
#   ✓ Embedded successfully (dim: 3072)
# Processing 55/40499: beverage_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 55/40499: beverage_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 56/40499: wrapping_paper
#   ✓ Embedded successfully (dim: 3072)
# Processing 56/40499: wrapping_paper
#   ✓ Embedded successfully (dim: 3072)
# Processing 57/40499: management_consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 57/40499: management_consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 58/40499: circle_g_japan
#   ✓ Embedded successfully (dim: 3072)
# Processing 58/40499: circle_g_japan
#   ✓ Embedded successfully (dim: 3072)
# Processing 59/40499: stone_surfaces
#   ✓ Embedded successfully (dim: 3072)
# Processing 59/40499: stone_surfaces
#   ✓ Embedded successfully (dim: 3072)
# Processing 60/40499: steelworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 60/40499: steelworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 61/40499: radio_podcast
#   ✓ Embedded successfully (dim: 3072)
# Processing 61/40499: radio_podcast
#   ✓ Embedded successfully (dim: 3072)
# Processing 62/40499: machine_components
#   ✓ Embedded successfully (dim: 3072)
# Processing 62/40499: machine_components
#   ✓ Embedded successfully (dim: 3072)
# Processing 63/40499: toys
#   ✓ Embedded successfully (dim: 3072)
# Processing 63/40499: toys
#   ✓ Embedded successfully (dim: 3072)
# Processing 64/40499: import_export
#   ✓ Embedded successfully (dim: 3072)
# Processing 64/40499: import_export
#   ✓ Embedded successfully (dim: 3072)
# Processing 65/40499: photographers_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 65/40499: photographers_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 66/40499: red_cross
#   ✓ Embedded successfully (dim: 3072)
# Processing 66/40499: red_cross
#   ✓ Embedded successfully (dim: 3072)
# Processing 67/40499: a_luxembourg
#   ✓ Embedded successfully (dim: 3072)
# Processing 67/40499: a_luxembourg
#   ✓ Embedded successfully (dim: 3072)
# Processing 68/40499: cultural_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 68/40499: cultural_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 69/40499: national_press_club
#   ✓ Embedded successfully (dim: 3072)
# Processing 69/40499: national_press_club
#   ✓ Embedded successfully (dim: 3072)
# Processing 70/40499: sports_teams
#   ✓ Embedded successfully (dim: 3072)
# Processing 70/40499: sports_teams
#   ✓ Embedded successfully (dim: 3072)
# Processing 71/40499: automobile_parts
#   ✓ Embedded successfully (dim: 3072)
# Processing 71/40499: automobile_parts
#   ✓ Embedded successfully (dim: 3072)
# Processing 72/40499: metal_processing
#   ✓ Embedded successfully (dim: 3072)
# Processing 72/40499: metal_processing
#   ✓ Embedded successfully (dim: 3072)
# Processing 73/40499: diamond_polishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 73/40499: diamond_polishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 74/40499: foundary_collective
#   ✓ Embedded successfully (dim: 3072)
# Processing 74/40499: foundary_collective
#   ✓ Embedded successfully (dim: 3072)
# Processing 75/40499: a_lines_netherlands_weave
#   ✓ Embedded successfully (dim: 3072)
# Processing 75/40499: a_lines_netherlands_weave
#   ✓ Embedded successfully (dim: 3072)
# Processing 76/40499: building_societies
#   ✓ Embedded successfully (dim: 3072)
# Processing 76/40499: building_societies
#   ✓ Embedded successfully (dim: 3072)
# Processing 77/40499: sport_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 77/40499: sport_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 78/40499: fuel_oil
#   ✓ Embedded successfully (dim: 3072)
# Processing 78/40499: fuel_oil
#   ✓ Embedded successfully (dim: 3072)
# Processing 79/40499: metallurgical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 79/40499: metallurgical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 80/40499: blood_donation
#   ✓ Embedded successfully (dim: 3072)
# Processing 80/40499: blood_donation
#   ✓ Embedded successfully (dim: 3072)
# Processing 81/40499: glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 81/40499: glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 82/40499: sports_club
#   ✓ Embedded successfully (dim: 3072)
# Processing 82/40499: sports_club
#   ✓ Embedded successfully (dim: 3072)
# Processing 83/40499: political_administration
#   ✓ Embedded successfully (dim: 3072)
# Processing 83/40499: political_administration
#   ✓ Embedded successfully (dim: 3072)
# Processing 84/40499: chris_yaneff
#   ✓ Embedded successfully (dim: 3072)
# Processing 84/40499: chris_yaneff
#   ✓ Embedded successfully (dim: 3072)
# Processing 85/40499: art_museum
#   ✓ Embedded successfully (dim: 3072)
# Processing 85/40499: art_museum
#   ✓ Embedded successfully (dim: 3072)
# Processing 86/40499: politics
#   ✓ Embedded successfully (dim: 3072)
# Processing 86/40499: politics
#   ✓ Embedded successfully (dim: 3072)
# Processing 87/40499: tiles
#   ✓ Embedded successfully (dim: 3072)
# Processing 87/40499: tiles
#   ✓ Embedded successfully (dim: 3072)
# Processing 88/40499: painting_tools_and_supplies
#   ✓ Embedded successfully (dim: 3072)
# Processing 88/40499: painting_tools_and_supplies
#   ✓ Embedded successfully (dim: 3072)
# Processing 89/40499: architects
#   ✓ Embedded successfully (dim: 3072)
# Processing 89/40499: architects
#   ✓ Embedded successfully (dim: 3072)
# Processing 90/40499: audio_equipment_store
#   ✓ Embedded successfully (dim: 3072)
# Processing 90/40499: audio_equipment_store
#   ✓ Embedded successfully (dim: 3072)
# Processing 91/40499: construction_material
#   ✓ Embedded successfully (dim: 3072)
# Processing 91/40499: construction_material
#   ✓ Embedded successfully (dim: 3072)
# Processing 92/40499: textile_solutions
#   ✓ Embedded successfully (dim: 3072)
# Processing 92/40499: textile_solutions
#   ✓ Embedded successfully (dim: 3072)
# Processing 93/40499: medical_information
#   ✓ Embedded successfully (dim: 3072)
# Processing 93/40499: medical_information
#   ✓ Embedded successfully (dim: 3072)
# Processing 94/40499: ed_lukas
#   ✓ Embedded successfully (dim: 3072)
# Processing 94/40499: ed_lukas
#   ✓ Embedded successfully (dim: 3072)
# Processing 95/40499: home_improvement
#   ✓ Embedded successfully (dim: 3072)
# Processing 95/40499: home_improvement
#   ✓ Embedded successfully (dim: 3072)
# Processing 96/40499: consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 96/40499: consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 97/40499: sustainable_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 97/40499: sustainable_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 98/40499: state_banks_organization
#   ✓ Embedded successfully (dim: 3072)
# Processing 98/40499: state_banks_organization
#   ✓ Embedded successfully (dim: 3072)
# Processing 99/40499: doors
#   ✓ Embedded successfully (dim: 3072)
# Processing 99/40499: doors
#   ✓ Embedded successfully (dim: 3072)
# Processing 100/40499: wholesale_distribution
#   ✓ Embedded successfully (dim: 3072)
# Processing 100/40499: wholesale_distribution
#   ✓ Embedded successfully (dim: 3072)
# Processing 101/40499: restaurant_dining
#   ✓ Embedded successfully (dim: 3072)
# Processing 101/40499: restaurant_dining
#   ✓ Embedded successfully (dim: 3072)
# Processing 102/40499: documentary_films
#   ✓ Embedded successfully (dim: 3072)
# Processing 102/40499: documentary_films
#   ✓ Embedded successfully (dim: 3072)
# Processing 103/40499: raul_perez_duarte_viesca
#   ✓ Embedded successfully (dim: 3072)
# Processing 103/40499: raul_perez_duarte_viesca
#   ✓ Embedded successfully (dim: 3072)
# Processing 104/40499: public_transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 104/40499: public_transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 105/40499: oil_industry_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 105/40499: oil_industry_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 106/40499: photography_book_app
#   ✓ Embedded successfully (dim: 3072)
# Processing 106/40499: photography_book_app
#   ✓ Embedded successfully (dim: 3072)
# Processing 107/40499: docter
#   ✓ Embedded successfully (dim: 3072)
# Processing 107/40499: docter
#   ✓ Embedded successfully (dim: 3072)
# Processing 108/40499: weather_studies_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 108/40499: weather_studies_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 109/40499: stefan_kanchev
#   ✓ Embedded successfully (dim: 3072)
# Processing 109/40499: stefan_kanchev
#   ✓ Embedded successfully (dim: 3072)
# Processing 110/40499: hotels_lodging
#   ✓ Embedded successfully (dim: 3072)
# Processing 110/40499: hotels_lodging
#   ✓ Embedded successfully (dim: 3072)
# Processing 111/40499: worlds_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 111/40499: worlds_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 112/40499: dental_laboratory
#   ✓ Embedded successfully (dim: 3072)
# Processing 112/40499: dental_laboratory
#   ✓ Embedded successfully (dim: 3072)
# Processing 113/40499: travel_tourism
#   ✓ Embedded successfully (dim: 3072)
# Processing 113/40499: travel_tourism
#   ✓ Embedded successfully (dim: 3072)
# Processing 114/40499: transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 114/40499: transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 115/40499: manufacturing_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 115/40499: manufacturing_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 116/40499: hemp_and_linen
#   ✓ Embedded successfully (dim: 3072)
# Processing 116/40499: hemp_and_linen
#   ✓ Embedded successfully (dim: 3072)
# Processing 117/40499: social_organization
#   ✓ Embedded successfully (dim: 3072)
# Processing 117/40499: social_organization
#   ✓ Embedded successfully (dim: 3072)
# Processing 118/40499: silvio_coppola
#   ✓ Embedded successfully (dim: 3072)
# Processing 118/40499: silvio_coppola
#   ✓ Embedded successfully (dim: 3072)
# Processing 119/40499: design_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 119/40499: design_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 120/40499: aviation_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 120/40499: aviation_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 121/40499: heating_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 121/40499: heating_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 122/40499: aluminium_accessories
#   ✓ Embedded successfully (dim: 3072)
# Processing 122/40499: aluminium_accessories
#   ✓ Embedded successfully (dim: 3072)
# Processing 123/40499: indurstial_engineering
#   ✓ Embedded successfully (dim: 3072)
# Processing 123/40499: indurstial_engineering
#   ✓ Embedded successfully (dim: 3072)
# Processing 124/40499: home_appliances
#   ✓ Embedded successfully (dim: 3072)
# Processing 124/40499: home_appliances
#   ✓ Embedded successfully (dim: 3072)
# Processing 125/40499: bookstore
#   ✓ Embedded successfully (dim: 3072)
# Processing 125/40499: bookstore
#   ✓ Embedded successfully (dim: 3072)
# Processing 126/40499: steel_manufacturing_global_construction
#   ✓ Embedded successfully (dim: 3072)
# Processing 126/40499: steel_manufacturing_global_construction
#   ✓ Embedded successfully (dim: 3072)
# Processing 127/40499: energy_utilities
#   ✓ Embedded successfully (dim: 3072)
# Processing 127/40499: energy_utilities
#   ✓ Embedded successfully (dim: 3072)
# Processing 128/40499: health_symposium
#   ✓ Embedded successfully (dim: 3072)
# Processing 128/40499: health_symposium
#   ✓ Embedded successfully (dim: 3072)
# Processing 129/40499: nakajo_masayoshi
#   ✓ Embedded successfully (dim: 3072)
# Processing 129/40499: nakajo_masayoshi
#   ✓ Embedded successfully (dim: 3072)
# Processing 130/40499: container_companies
#   ✓ Embedded successfully (dim: 3072)
# Processing 130/40499: container_companies
#   ✓ Embedded successfully (dim: 3072)
# Processing 131/40499: university_liaison
#   ✓ Embedded successfully (dim: 3072)
# Processing 131/40499: university_liaison
#   ✓ Embedded successfully (dim: 3072)
# Processing 132/40499: elections_campaign
#   ✓ Embedded successfully (dim: 3072)
# Processing 132/40499: elections_campaign
#   ✓ Embedded successfully (dim: 3072)
# Processing 133/40499: marine_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 133/40499: marine_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 134/40499: metalworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 134/40499: metalworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 135/40499: government_public
#   ✓ Embedded successfully (dim: 3072)
# Processing 135/40499: government_public
#   ✓ Embedded successfully (dim: 3072)
# Processing 136/40499: food_production
#   ✓ Embedded successfully (dim: 3072)
# Processing 136/40499: food_production
#   ✓ Embedded successfully (dim: 3072)
# Processing 137/40499: recording_series
#   ✓ Embedded successfully (dim: 3072)
# Processing 137/40499: recording_series
#   ✓ Embedded successfully (dim: 3072)
# Processing 138/40499: music_industry
#   ✓ Embedded successfully (dim: 3072)
# Processing 138/40499: music_industry
#   ✓ Embedded successfully (dim: 3072)
# Processing 139/40499: nuclear_research
#   ✓ Embedded successfully (dim: 3072)
# Processing 139/40499: nuclear_research
#   ✓ Embedded successfully (dim: 3072)
# Processing 140/40499: chipboard
#   ✓ Embedded successfully (dim: 3072)
# Processing 140/40499: chipboard
#   ✓ Embedded successfully (dim: 3072)
# Processing 141/40499: carpets
#   ✓ Embedded successfully (dim: 3072)
# Processing 141/40499: carpets
#   ✓ Embedded successfully (dim: 3072)
# Processing 142/40499: trade_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 142/40499: trade_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 143/40499: religious_faith
#   ✓ Embedded successfully (dim: 3072)
# Processing 143/40499: religious_faith
#   ✓ Embedded successfully (dim: 3072)
# Processing 144/40499: music_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 144/40499: music_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 145/40499: electro_physical_instruments
#   ✓ Embedded successfully (dim: 3072)
# Processing 145/40499: electro_physical_instruments
#   ✓ Embedded successfully (dim: 3072)
# Processing 146/40499: construction_materials
#   ✓ Embedded successfully (dim: 3072)
# Processing 146/40499: construction_materials
#   ✓ Embedded successfully (dim: 3072)
# Processing 147/40499: bridge_maintenance
#   ✓ Embedded successfully (dim: 3072)
# Processing 147/40499: bridge_maintenance
#   ✓ Embedded successfully (dim: 3072)
# Processing 148/40499: journalists_assiciation
#   ✓ Embedded successfully (dim: 3072)
# Processing 148/40499: journalists_assiciation
#   ✓ Embedded successfully (dim: 3072)
# Processing 149/40499: security_safety
#   ✓ Embedded successfully (dim: 3072)
# Processing 149/40499: security_safety
#   ✓ Embedded successfully (dim: 3072)
# Processing 150/40499: photography_video
#   ✓ Embedded successfully (dim: 3072)
# Processing 150/40499: photography_video
#   ✓ Embedded successfully (dim: 3072)
# Processing 151/40499: trade_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 151/40499: trade_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 152/40499: knitting_factory
#   ✓ Embedded successfully (dim: 3072)
# Processing 152/40499: knitting_factory
#   ✓ Embedded successfully (dim: 3072)
# Processing 153/40499: ernesto_lehfeld
#   ✓ Embedded successfully (dim: 3072)
# Processing 153/40499: ernesto_lehfeld
#   ✓ Embedded successfully (dim: 3072)
# Processing 154/40499: meat_processing_machinery
#   ✓ Embedded successfully (dim: 3072)
# Processing 154/40499: meat_processing_machinery
#   ✓ Embedded successfully (dim: 3072)
# Processing 155/40499: light_installations
#   ✓ Embedded successfully (dim: 3072)
# Processing 155/40499: light_installations
#   ✓ Embedded successfully (dim: 3072)
# Processing 156/40499: canned_food
#   ✓ Embedded successfully (dim: 3072)
# Processing 156/40499: canned_food
#   ✓ Embedded successfully (dim: 3072)
# Processing 157/40499: business_consultant
#   ✓ Embedded successfully (dim: 3072)
# Processing 157/40499: business_consultant
#   ✓ Embedded successfully (dim: 3072)
# Processing 158/40499: retail_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 158/40499: retail_general
#   ✓ Embedded successfully (dim: 3072)
# Processing 159/40499: trade_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 159/40499: trade_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 160/40499: marketing_and_communications
#   ✓ Embedded successfully (dim: 3072)
# Processing 160/40499: marketing_and_communications
#   ✓ Embedded successfully (dim: 3072)
# Processing 161/40499: bathing
#   ✓ Embedded successfully (dim: 3072)
# Processing 161/40499: bathing
#   ✓ Embedded successfully (dim: 3072)
# Processing 162/40499: nonprofit_charity
#   ✓ Embedded successfully (dim: 3072)
# Processing 162/40499: nonprofit_charity
#   ✓ Embedded successfully (dim: 3072)
# Processing 163/40499: prinr_workshop_gallery
#   ✓ Embedded successfully (dim: 3072)
# Processing 163/40499: prinr_workshop_gallery
#   ✓ Embedded successfully (dim: 3072)
# Processing 164/40499: industrial_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 164/40499: industrial_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 165/40499: cruz_novillo
#   ✓ Embedded successfully (dim: 3072)
# Processing 165/40499: cruz_novillo
#   ✓ Embedded successfully (dim: 3072)
# Processing 166/40499: painter
#   ✓ Embedded successfully (dim: 3072)
# Processing 166/40499: painter
#   ✓ Embedded successfully (dim: 3072)
# Processing 167/40499: japan_round
#   ✓ Embedded successfully (dim: 3072)
# Processing 167/40499: japan_round
#   ✓ Embedded successfully (dim: 3072)
# Processing 168/40499: packaging
#   ✓ Embedded successfully (dim: 3072)
# Processing 168/40499: packaging
#   ✓ Embedded successfully (dim: 3072)
# Processing 169/40499: investment_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 169/40499: investment_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 170/40499: max_huber
#   ✓ Embedded successfully (dim: 3072)
# Processing 170/40499: max_huber
#   ✓ Embedded successfully (dim: 3072)
# Processing 171/40499: tv_channel
#   ✓ Embedded successfully (dim: 3072)
# Processing 171/40499: tv_channel
#   ✓ Embedded successfully (dim: 3072)
# Processing 172/40499: acoustic_devices
#   ✓ Embedded successfully (dim: 3072)
# Processing 172/40499: acoustic_devices
#   ✓ Embedded successfully (dim: 3072)
# Processing 173/40499: floor_coverings
#   ✓ Embedded successfully (dim: 3072)
# Processing 173/40499: floor_coverings
#   ✓ Embedded successfully (dim: 3072)
# Processing 174/40499: automobile_dealer
#   ✓ Embedded successfully (dim: 3072)
# Processing 174/40499: automobile_dealer
#   ✓ Embedded successfully (dim: 3072)
# Processing 175/40499: energy_company
#   ✓ Embedded successfully (dim: 3072)
# Processing 175/40499: energy_company
#   ✓ Embedded successfully (dim: 3072)
# Processing 176/40499: urban_planning
#   ✓ Embedded successfully (dim: 3072)
# Processing 176/40499: urban_planning
#   ✓ Embedded successfully (dim: 3072)
# Processing 177/40499: jean_claude_guenette
#   ✓ Embedded successfully (dim: 3072)
# Processing 177/40499: jean_claude_guenette
#   ✓ Embedded successfully (dim: 3072)
# Processing 178/40499: cafe_coffee
#   ✓ Embedded successfully (dim: 3072)
# Processing 178/40499: cafe_coffee
#   ✓ Embedded successfully (dim: 3072)
# Processing 179/40499: hospital_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 179/40499: hospital_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 180/40499: financial_consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 180/40499: financial_consultancy
#   ✓ Embedded successfully (dim: 3072)
# Processing 181/40499: hans_kundig
#   ✓ Embedded successfully (dim: 3072)
# Processing 181/40499: hans_kundig
#   ✓ Embedded successfully (dim: 3072)
# Processing 182/40499: footwear_leather
#   ✓ Embedded successfully (dim: 3072)
# Processing 182/40499: footwear_leather
#   ✓ Embedded successfully (dim: 3072)
# Processing 183/40499: local_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 183/40499: local_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 184/40499: warehouse_and_transportation
#   ✓ Embedded successfully (dim: 3072)
# Processing 184/40499: warehouse_and_transportation
#   ✓ Embedded successfully (dim: 3072)
# Processing 185/40499: artisit_carving
#   ✓ Embedded successfully (dim: 3072)
# Processing 185/40499: artisit_carving
#   ✓ Embedded successfully (dim: 3072)
# Processing 186/40499: national_film_board
#   ✓ Embedded successfully (dim: 3072)
# Processing 186/40499: national_film_board
#   ✓ Embedded successfully (dim: 3072)
# Processing 187/40499: employment_agency
#   ✓ Embedded successfully (dim: 3072)
# Processing 187/40499: employment_agency
#   ✓ Embedded successfully (dim: 3072)
# Processing 188/40499: cultural_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 188/40499: cultural_organisation
#   ✓ Embedded successfully (dim: 3072)
# Processing 189/40499: credit_investment_firm
#   ✓ Embedded successfully (dim: 3072)
# Processing 189/40499: credit_investment_firm
#   ✓ Embedded successfully (dim: 3072)
# Processing 190/40499: beauty_cosmetics
#   ✓ Embedded successfully (dim: 3072)
# Processing 190/40499: beauty_cosmetics
#   ✓ Embedded successfully (dim: 3072)
# Processing 191/40499: salt
#   ✓ Embedded successfully (dim: 3072)
# Processing 191/40499: salt
#   ✓ Embedded successfully (dim: 3072)
# Processing 192/40499: thermoacoustic_insulation
#   ✓ Embedded successfully (dim: 3072)
# Processing 192/40499: thermoacoustic_insulation
#   ✓ Embedded successfully (dim: 3072)
# Processing 193/40499: color_film_recorders
#   ✓ Embedded successfully (dim: 3072)
# Processing 193/40499: color_film_recorders
#   ✓ Embedded successfully (dim: 3072)
# Processing 194/40499: promotion_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 194/40499: promotion_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 195/40499: animal_feed
#   ✓ Embedded successfully (dim: 3072)
# Processing 195/40499: animal_feed
#   ✓ Embedded successfully (dim: 3072)
# Processing 196/40499: energy_research_and_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 196/40499: energy_research_and_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 197/40499: product_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 197/40499: product_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 198/40499: thermal_insulation
#   ✓ Embedded successfully (dim: 3072)
# Processing 198/40499: thermal_insulation
#   ✓ Embedded successfully (dim: 3072)
# Processing 199/40499: legal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 199/40499: legal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 200/40499: fish
#   ✓ Embedded successfully (dim: 3072)
# Processing 200/40499: fish
#   ✓ Embedded successfully (dim: 3072)
# Processing 201/40499: luis_ortega_de_uhler
#   ✓ Embedded successfully (dim: 3072)
# Processing 201/40499: luis_ortega_de_uhler
#   ✓ Embedded successfully (dim: 3072)
# Processing 202/40499: proffessional_associations
#   ✓ Embedded successfully (dim: 3072)
# Processing 202/40499: proffessional_associations
#   ✓ Embedded successfully (dim: 3072)
# Processing 203/40499: felix_beltran
#   ✓ Embedded successfully (dim: 3072)
# Processing 203/40499: felix_beltran
#   ✓ Embedded successfully (dim: 3072)
# Processing 204/40499: arts_venue
#   ✓ Embedded successfully (dim: 3072)
# Processing 204/40499: arts_venue
#   ✓ Embedded successfully (dim: 3072)
# Processing 205/40499: national_development_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 205/40499: national_development_office
#   ✓ Embedded successfully (dim: 3072)
# Processing 206/40499: anton_stankowski
#   ✓ Embedded successfully (dim: 3072)
# Processing 206/40499: anton_stankowski
#   ✓ Embedded successfully (dim: 3072)
# Processing 207/40499: agricultural_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 207/40499: agricultural_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 208/40499: craft_supplier
#   ✓ Embedded successfully (dim: 3072)
# Processing 208/40499: craft_supplier
#   ✓ Embedded successfully (dim: 3072)
# Processing 209/40499: real_estate_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 209/40499: real_estate_development
#   ✓ Embedded successfully (dim: 3072)
# Processing 210/40499: trade_promotion
#   ✓ Embedded successfully (dim: 3072)
# Processing 210/40499: trade_promotion
#   ✓ Embedded successfully (dim: 3072)
# Processing 211/40499: metallurgy
#   ✓ Embedded successfully (dim: 3072)
# Processing 211/40499: metallurgy
#   ✓ Embedded successfully (dim: 3072)
# Processing 212/40499: marcel_wyss
#   ✓ Embedded successfully (dim: 3072)
# Processing 212/40499: marcel_wyss
#   ✓ Embedded successfully (dim: 3072)
# Processing 213/40499: inport_export
#   ✓ Embedded successfully (dim: 3072)
# Processing 213/40499: inport_export
#   ✓ Embedded successfully (dim: 3072)
# Processing 214/40499: industrial_steel
#   ✓ Embedded successfully (dim: 3072)
# Processing 214/40499: industrial_steel
#   ✓ Embedded successfully (dim: 3072)
# Processing 215/40499: fruits
#   ✓ Embedded successfully (dim: 3072)
# Processing 215/40499: fruits
#   ✓ Embedded successfully (dim: 3072)
# Processing 216/40499: machines
#   ✓ Embedded successfully (dim: 3072)
# Processing 216/40499: machines
#   ✓ Embedded successfully (dim: 3072)
# Processing 217/40499: printing_machinery
#   ✓ Embedded successfully (dim: 3072)
# Processing 217/40499: printing_machinery
#   ✓ Embedded successfully (dim: 3072)
# Processing 218/40499: milk_producers_union
#   ✓ Embedded successfully (dim: 3072)
# Processing 218/40499: milk_producers_union
#   ✓ Embedded successfully (dim: 3072)
# Processing 219/40499: marine_hardware
#   ✓ Embedded successfully (dim: 3072)
# Processing 219/40499: marine_hardware
#   ✓ Embedded successfully (dim: 3072)
# Processing 220/40499: management_institute
#   ✓ Embedded successfully (dim: 3072)
# Processing 220/40499: management_institute
#   ✓ Embedded successfully (dim: 3072)
# Processing 221/40499: trade
#   ✓ Embedded successfully (dim: 3072)
# Processing 221/40499: trade
#   ✓ Embedded successfully (dim: 3072)
# Processing 222/40499: world_crafts_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 222/40499: world_crafts_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 223/40499: landscaping_garden
#   ✓ Embedded successfully (dim: 3072)
# Processing 223/40499: landscaping_garden
#   ✓ Embedded successfully (dim: 3072)
# Processing 224/40499: locksmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 224/40499: locksmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 225/40499: milk_production
#   ✓ Embedded successfully (dim: 3072)
# Processing 225/40499: milk_production
#   ✓ Embedded successfully (dim: 3072)
# Processing 226/40499: speech_therapy
#   ✓ Embedded successfully (dim: 3072)
# Processing 226/40499: speech_therapy
#   ✓ Embedded successfully (dim: 3072)
# Processing 227/40499: wood_shavings
#   ✓ Embedded successfully (dim: 3072)
# Processing 227/40499: wood_shavings
#   ✓ Embedded successfully (dim: 3072)
# Processing 228/40499: art_curation
#   ✓ Embedded successfully (dim: 3072)
# Processing 228/40499: art_curation
#   ✓ Embedded successfully (dim: 3072)
# Processing 229/40499: opera_company
#   ✓ Embedded successfully (dim: 3072)
# Processing 229/40499: opera_company
#   ✓ Embedded successfully (dim: 3072)
# Processing 230/40499: tailor
#   ✓ Embedded successfully (dim: 3072)
# Processing 230/40499: tailor
#   ✓ Embedded successfully (dim: 3072)
# Processing 231/40499: color_photo_reproductions
#   ✓ Embedded successfully (dim: 3072)
# Processing 231/40499: color_photo_reproductions
#   ✓ Embedded successfully (dim: 3072)
# Processing 232/40499: industry
#   ✓ Embedded successfully (dim: 3072)
# Processing 232/40499: industry
#   ✓ Embedded successfully (dim: 3072)
# Processing 233/40499: exhibition_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 233/40499: exhibition_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 234/40499: libraries
#   ✓ Embedded successfully (dim: 3072)
# Processing 234/40499: libraries
#   ✓ Embedded successfully (dim: 3072)
# Processing 235/40499: centre_of_culture
#   ✓ Embedded successfully (dim: 3072)
# Processing 235/40499: centre_of_culture
#   ✓ Embedded successfully (dim: 3072)
# Processing 236/40499: interior_architecture
#   ✓ Embedded successfully (dim: 3072)
# Processing 236/40499: interior_architecture
#   ✓ Embedded successfully (dim: 3072)
# Processing 237/40499: government_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 237/40499: government_council
#   ✓ Embedded successfully (dim: 3072)
# Processing 238/40499: yasuhisa_iguchi
#   ✓ Embedded successfully (dim: 3072)
# Processing 238/40499: yasuhisa_iguchi
#   ✓ Embedded successfully (dim: 3072)
# Processing 239/40499: design_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 239/40499: design_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 240/40499: automotive_transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 240/40499: automotive_transport
#   ✓ Embedded successfully (dim: 3072)
# Processing 241/40499: can_maufacturer
#   ✓ Embedded successfully (dim: 3072)
# Processing 241/40499: can_maufacturer
#   ✓ Embedded successfully (dim: 3072)
# Processing 242/40499: jewellery_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 242/40499: jewellery_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 243/40499: chemistry_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 243/40499: chemistry_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 244/40499: goldsmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 244/40499: goldsmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 245/40499: mineral_water
#   ✓ Embedded successfully (dim: 3072)
# Processing 245/40499: mineral_water
#   ✓ Embedded successfully (dim: 3072)
# Processing 246/40499: cultural_exchange
#   ✓ Embedded successfully (dim: 3072)
# Processing 246/40499: cultural_exchange
#   ✓ Embedded successfully (dim: 3072)
# Processing 247/40499: photography_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 247/40499: photography_fair
#   ✓ Embedded successfully (dim: 3072)
# Processing 248/40499: film_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 248/40499: film_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 249/40499: douglas_williams
#   ✓ Embedded successfully (dim: 3072)
# Processing 249/40499: douglas_williams
#   ✓ Embedded successfully (dim: 3072)
# Processing 250/40499: leather_and_wool
#   ✓ Embedded successfully (dim: 3072)
# Processing 250/40499: leather_and_wool
#   ✓ Embedded successfully (dim: 3072)
# Processing 251/40499: importers
#   ✓ Embedded successfully (dim: 3072)
# Processing 251/40499: importers
#   ✓ Embedded successfully (dim: 3072)
# Processing 252/40499: postal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 252/40499: postal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 253/40499: art_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 253/40499: art_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 254/40499: poultry_farming
#   ✓ Embedded successfully (dim: 3072)
# Processing 254/40499: poultry_farming
#   ✓ Embedded successfully (dim: 3072)
# Processing 255/40499: metal_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 255/40499: metal_goods
#   ✓ Embedded successfully (dim: 3072)
# Processing 256/40499: illustrators_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 256/40499: illustrators_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 257/40499: musical_instruments
#   ✓ Embedded successfully (dim: 3072)
# Processing 257/40499: musical_instruments
#   ✓ Embedded successfully (dim: 3072)
# Processing 258/40499: mining_extraction
#   ✓ Embedded successfully (dim: 3072)
# Processing 258/40499: mining_extraction
#   ✓ Embedded successfully (dim: 3072)
# Processing 259/40499: bar_nightlife
#   ✓ Embedded successfully (dim: 3072)
# Processing 259/40499: bar_nightlife
#   ✓ Embedded successfully (dim: 3072)
# Processing 260/40499: childrens_books
#   ✓ Embedded successfully (dim: 3072)
# Processing 260/40499: childrens_books
#   ✓ Embedded successfully (dim: 3072)
# Processing 261/40499: water_sensitive_urban_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 261/40499: water_sensitive_urban_design
#   ✓ Embedded successfully (dim: 3072)
# Processing 262/40499: hotel_chain
#   ✓ Embedded successfully (dim: 3072)
# Processing 262/40499: hotel_chain
#   ✓ Embedded successfully (dim: 3072)
# Processing 263/40499: shoe_corporation
#   ✓ Embedded successfully (dim: 3072)
# Processing 263/40499: shoe_corporation
#   ✓ Embedded successfully (dim: 3072)
# Processing 264/40499: national_park
#   ✓ Embedded successfully (dim: 3072)
# Processing 264/40499: national_park
#   ✓ Embedded successfully (dim: 3072)
# Processing 265/40499: tobacco_vaping
#   ✓ Embedded successfully (dim: 3072)
# Processing 265/40499: tobacco_vaping
#   ✓ Embedded successfully (dim: 3072)
# Processing 266/40499: cartography
#   ✓ Embedded successfully (dim: 3072)
# Processing 266/40499: cartography
#   ✓ Embedded successfully (dim: 3072)
# Processing 267/40499: advertising_and_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 267/40499: advertising_and_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 268/40499: media_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 268/40499: media_publishing
#   ✓ Embedded successfully (dim: 3072)
# Processing 269/40499: music_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 269/40499: music_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 270/40499: water_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 270/40499: water_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 271/40499: materials_resource
#   ✓ Embedded successfully (dim: 3072)
# Processing 271/40499: materials_resource
#   ✓ Embedded successfully (dim: 3072)
# Processing 272/40499: fashion_management_blog
#   ✓ Embedded successfully (dim: 3072)
# Processing 272/40499: fashion_management_blog
#   ✓ Embedded successfully (dim: 3072)
# Processing 273/40499: educational_exchange
#   ✓ Embedded successfully (dim: 3072)
# Processing 273/40499: educational_exchange
#   ✓ Embedded successfully (dim: 3072)
# Processing 274/40499: building_workers_union
#   ✓ Embedded successfully (dim: 3072)
# Processing 274/40499: building_workers_union
#   ✓ Embedded successfully (dim: 3072)
# Processing 275/40499: ice
#   ✓ Embedded successfully (dim: 3072)
# Processing 275/40499: ice
#   ✓ Embedded successfully (dim: 3072)
# Processing 276/40499: furniture_design_event_organisers
#   ✓ Embedded successfully (dim: 3072)
# Processing 276/40499: furniture_design_event_organisers
#   ✓ Embedded successfully (dim: 3072)
# Processing 277/40499: agricultural_tools
#   ✓ Embedded successfully (dim: 3072)
# Processing 277/40499: agricultural_tools
#   ✓ Embedded successfully (dim: 3072)
# Processing 278/40499: workers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 278/40499: workers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 279/40499: art_glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 279/40499: art_glass
#   ✓ Embedded successfully (dim: 3072)
# Processing 280/40499: waterproofing
#   ✓ Embedded successfully (dim: 3072)
# Processing 280/40499: waterproofing
#   ✓ Embedded successfully (dim: 3072)
# Processing 281/40499: izi
#   ✓ Embedded successfully (dim: 3072)
# Processing 281/40499: izi
#   ✓ Embedded successfully (dim: 3072)
# Processing 282/40499: air_conditioning
#   ✓ Embedded successfully (dim: 3072)
# Processing 282/40499: air_conditioning
#   ✓ Embedded successfully (dim: 3072)
# Processing 283/40499: gaming_entertainment
#   ✓ Embedded successfully (dim: 3072)
# Processing 283/40499: gaming_entertainment
#   ✓ Embedded successfully (dim: 3072)
# Processing 284/40499: computer_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 284/40499: computer_systems
#   ✓ Embedded successfully (dim: 3072)
# Processing 285/40499: typography_and_lithography
#   ✓ Embedded successfully (dim: 3072)
# Processing 285/40499: typography_and_lithography
#   ✓ Embedded successfully (dim: 3072)
# Processing 286/40499: gavin_healey
#   ✓ Embedded successfully (dim: 3072)
# Processing 286/40499: gavin_healey
#   ✓ Embedded successfully (dim: 3072)
# Processing 287/40499: boilers
#   ✓ Embedded successfully (dim: 3072)
# Processing 287/40499: boilers
#   ✓ Embedded successfully (dim: 3072)
# Processing 288/40499: digital_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 288/40499: digital_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 289/40499: chemical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 289/40499: chemical_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 290/40499: cycling_studio
#   ✓ Embedded successfully (dim: 3072)
# Processing 290/40499: cycling_studio
#   ✓ Embedded successfully (dim: 3072)
# Processing 291/40499: architecture_foundation
#   ✓ Embedded successfully (dim: 3072)
# Processing 291/40499: architecture_foundation
#   ✓ Embedded successfully (dim: 3072)
# Processing 292/40499: light_bulbs
#   ✓ Embedded successfully (dim: 3072)
# Processing 292/40499: light_bulbs
#   ✓ Embedded successfully (dim: 3072)
# Processing 293/40499: industry_summits_organiser
#   ✓ Embedded successfully (dim: 3072)
# Processing 293/40499: industry_summits_organiser
#   ✓ Embedded successfully (dim: 3072)
# Processing 294/40499: photocopiers
#   ✓ Embedded successfully (dim: 3072)
# Processing 294/40499: photocopiers
#   ✓ Embedded successfully (dim: 3072)
# Processing 295/40499: piston_rings
#   ✓ Embedded successfully (dim: 3072)
# Processing 295/40499: piston_rings
#   ✓ Embedded successfully (dim: 3072)
# Processing 296/40499: real_estate_commercial
#   ✓ Embedded successfully (dim: 3072)
# Processing 296/40499: real_estate_commercial
#   ✓ Embedded successfully (dim: 3072)
# Processing 297/40499: dairy_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 297/40499: dairy_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 298/40499: measuring_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 298/40499: measuring_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 299/40499: measuring_technologies
#   ✓ Embedded successfully (dim: 3072)
# Processing 299/40499: measuring_technologies
#   ✓ Embedded successfully (dim: 3072)
# Processing 300/40499: bistronomy
#   ✓ Embedded successfully (dim: 3072)
# Processing 300/40499: bistronomy
#   ✓ Embedded successfully (dim: 3072)
# Processing 301/40499: fittings_and_washers
#   ✓ Embedded successfully (dim: 3072)
# Processing 301/40499: fittings_and_washers
#   ✓ Embedded successfully (dim: 3072)
# Processing 302/40499: typesetting
#   ✓ Embedded successfully (dim: 3072)
# Processing 302/40499: typesetting
#   ✓ Embedded successfully (dim: 3072)
# Processing 303/40499: kitchen_appliances
#   ✓ Embedded successfully (dim: 3072)
# Processing 303/40499: kitchen_appliances
#   ✓ Embedded successfully (dim: 3072)
# Processing 304/40499: synthetic_fibers
#   ✓ Embedded successfully (dim: 3072)
# Processing 304/40499: synthetic_fibers
#   ✓ Embedded successfully (dim: 3072)
# Processing 305/40499: energy_supplier
#   ✓ Embedded successfully (dim: 3072)
# Processing 305/40499: energy_supplier
#   ✓ Embedded successfully (dim: 3072)
# Processing 306/40499: youth_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 306/40499: youth_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 307/40499: ropes
#   ✓ Embedded successfully (dim: 3072)
# Processing 307/40499: ropes
#   ✓ Embedded successfully (dim: 3072)
# Processing 308/40499: pipes
#   ✓ Embedded successfully (dim: 3072)
# Processing 308/40499: pipes
#   ✓ Embedded successfully (dim: 3072)
# Processing 309/40499: ceramics
#   ✓ Embedded successfully (dim: 3072)
# Processing 309/40499: ceramics
#   ✓ Embedded successfully (dim: 3072)
# Processing 310/40499: cafeteria
#   ✓ Embedded successfully (dim: 3072)
# Processing 310/40499: cafeteria
#   ✓ Embedded successfully (dim: 3072)
# ...
# Processing 496/40499: cultural_center
#   ✓ Embedded successfully (dim: 3072)
# Processing 497/40499: architectural_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 497/40499: architectural_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 498/40499: laboratory_equipment
#   ✓ Embedded successfully (dim: 3072)
# Processing 498/40499: laboratory_equipment
#   ✓ Embedded successfully (dim: 3072)
# Processing 499/40499: art_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 499/40499: art_festival
#   ✓ Embedded successfully (dim: 3072)
# Processing 500/40499: aerospace_defense
#   ✓ Embedded successfully (dim: 3072)
# Processing 500/40499: aerospace_defense
#   ✓ Embedded successfully (dim: 3072)
# Processing 501/40499: scholarly_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 501/40499: scholarly_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 502/40499: rail_transport_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 502/40499: rail_transport_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 503/40499: car_parts
#   ✓ Embedded successfully (dim: 3072)
# Processing 503/40499: car_parts
#   ✓ Embedded successfully (dim: 3072)
# Processing 504/40499: technology_sales_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 504/40499: technology_sales_conference
#   ✓ Embedded successfully (dim: 3072)
# Processing 505/40499: parks
#   ✓ Embedded successfully (dim: 3072)
# Processing 505/40499: parks
#   ✓ Embedded successfully (dim: 3072)
# Processing 506/40499: design_promotion
#   ✓ Embedded successfully (dim: 3072)
# Processing 506/40499: design_promotion
#   ✓ Embedded successfully (dim: 3072)
# Processing 507/40499: executive_recruitment
#   ✓ Embedded successfully (dim: 3072)
# Processing 507/40499: executive_recruitment
#   ✓ Embedded successfully (dim: 3072)
# Processing 508/40499: dental_clinic
#   ✓ Embedded successfully (dim: 3072)
# Processing 508/40499: dental_clinic
#   ✓ Embedded successfully (dim: 3072)
# Processing 509/40499: ironworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 509/40499: ironworks
#   ✓ Embedded successfully (dim: 3072)
# Processing 510/40499: engineering_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 510/40499: engineering_products
#   ✓ Embedded successfully (dim: 3072)
# Processing 511/40499: oil_company_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 511/40499: oil_company_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 512/40499: design_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 512/40499: design_group
#   ✓ Embedded successfully (dim: 3072)
# Processing 513/40499: circle_italy_lines
#   ✓ Embedded successfully (dim: 3072)
# Processing 513/40499: circle_italy_lines
#   ✓ Embedded successfully (dim: 3072)
# Processing 514/40499: network_of_health_centers
#   ✓ Embedded successfully (dim: 3072)
# Processing 514/40499: network_of_health_centers
#   ✓ Embedded successfully (dim: 3072)
# Processing 515/40499: florent_garnier
#   ✓ Embedded successfully (dim: 3072)
# Processing 515/40499: florent_garnier
#   ✓ Embedded successfully (dim: 3072)
# Processing 516/40499: flowers
#   ✓ Embedded successfully (dim: 3072)
# Processing 516/40499: flowers
#   ✓ Embedded successfully (dim: 3072)
# Processing 517/40499: brakes
#   ✓ Embedded successfully (dim: 3072)
# Processing 517/40499: brakes
#   ✓ Embedded successfully (dim: 3072)
# Processing 518/40499: fitness_health
#   ✓ Embedded successfully (dim: 3072)
# Processing 518/40499: fitness_health
#   ✓ Embedded successfully (dim: 3072)
# Processing 519/40499: printers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 519/40499: printers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 520/40499: lance_wyman
#   ✓ Embedded successfully (dim: 3072)
# Processing 520/40499: lance_wyman
#   ✓ Embedded successfully (dim: 3072)
# Processing 521/40499: sensory_research_institute
#   ✓ Embedded successfully (dim: 3072)
# Processing 521/40499: sensory_research_institute
#   ✓ Embedded successfully (dim: 3072)
# Processing 522/40499: film_animation
#   ✓ Embedded successfully (dim: 3072)
# Processing 522/40499: film_animation
#   ✓ Embedded successfully (dim: 3072)
# Processing 523/40499: graphic_designers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 523/40499: graphic_designers_association
#   ✓ Embedded successfully (dim: 3072)
# Processing 524/40499: asbestos
#   ✓ Embedded successfully (dim: 3072)
# Processing 524/40499: asbestos
#   ✓ Embedded successfully (dim: 3072)
# Processing 525/40499: student_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 525/40499: student_magazine
#   ✓ Embedded successfully (dim: 3072)
# Processing 526/40499: oil_and_gas
#   ✓ Embedded successfully (dim: 3072)
# Processing 526/40499: oil_and_gas
#   ✓ Embedded successfully (dim: 3072)
# Processing 527/40499: olive_oil
#   ✓ Embedded successfully (dim: 3072)
# Processing 527/40499: olive_oil
#   ✓ Embedded successfully (dim: 3072)
# Processing 528/40499: jewellery_importation
#   ✓ Embedded successfully (dim: 3072)
# Processing 528/40499: jewellery_importation
#   ✓ Embedded successfully (dim: 3072)
# Processing 529/40499: fishing_cooperative
#   ✓ Embedded successfully (dim: 3072)
# Processing 529/40499: fishing_cooperative
#   ✓ Embedded successfully (dim: 3072)
# Processing 530/40499: coppersmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 530/40499: coppersmiths
#   ✓ Embedded successfully (dim: 3072)
# Processing 531/40499: ship_windows
#   ✓ Embedded successfully (dim: 3072)
# Processing 531/40499: ship_windows
#   ✓ Embedded successfully (dim: 3072)
# Processing 532/40499: elevators
#   ✓ Embedded successfully (dim: 3072)
# Processing 532/40499: elevators
#   ✓ Embedded successfully (dim: 3072)
# Processing 533/40499: annual_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 533/40499: annual_exhibition
#   ✓ Embedded successfully (dim: 3072)
# Processing 534/40499: appetite_suppressant
#   ✓ Embedded successfully (dim: 3072)
# Processing 534/40499: appetite_suppressant
#   ✓ Embedded successfully (dim: 3072)
# Processing 535/40499: energy_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 535/40499: energy_technology
#   ✓ Embedded successfully (dim: 3072)
# Processing 536/40499: emergency_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 536/40499: emergency_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 537/40499: animal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 537/40499: animal_services
#   ✓ Embedded successfully (dim: 3072)
# Processing 538/40499: electric_power
#   ✓ Embedded successfully (dim: 3072)
# Processing 538/40499: electric_power
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 27
#      24 for i, category in enumerate(unique_categories, 1):
#      25     print(f"Processing {i}/{total_categories}: {category}")
# ---> 27     embedding = get_embedding(category)
#      29     if embedding is not None:
#      30         category_embeddings[category] = embedding
#
# Cell In[3], line 22, in get_embedding(text, model, max_retries, delay)
#      19         print(f"Warning: Empty text provided")
#      20         return None
# ---> 22     response = client.embeddings.create(
#      23         input=text,
#      24         model=model
#      25     )
#      26     return response.data[0].embedding
#      28 except Exception as e:
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Step 3: Summary and final output
print("\n=== Step 3: Summary ===")

# Update paths for the outputs we actually created
output_unique_category_embeddings = Path('../output/amazing_logos_v4/data/unique_category_embeddings.json')

print(f"Configuration used:")
print(f"  - Computed consolidation map embeddings: {COMPUTE_CONSOLIDATION_EMBEDDINGS}")
print(f"  - Computed category embeddings: {COMPUTE_CATEGORY_EMBEDDINGS}")
print()

if COMPUTE_CONSOLIDATION_EMBEDDINGS or output_consolidation_embeddings.exists():
    print(f"Consolidation map embeddings: {len(consolidation_embeddings)} keys")
    if output_consolidation_embeddings.exists():
        print(f"  Saved to: {output_consolidation_embeddings}")
        print(f"  File size: {output_consolidation_embeddings.stat().st_size:,} bytes")

if COMPUTE_CATEGORY_EMBEDDINGS or output_unique_category_embeddings.exists():
    print(f"Unique category embeddings: {len(category_embeddings)} categories")
    if output_unique_category_embeddings.exists():
        print(f"  Saved to: {output_unique_category_embeddings}")
        print(f"  File size: {output_unique_category_embeddings.stat().st_size:,} bytes")

# Show some category embedding examples if available
if category_embeddings:
    print(f"\nExample categories with embeddings:")
    for i, (category, embedding) in enumerate(list(category_embeddings.items())[:5]):
        print(f"  {i+1}. '{category}' (embedding dim: {len(embedding)})")

print(f"\n✓ Embedding preparation completed!")
print(f"\nNext steps:")
print(f"1. Load the unique category embeddings JSON file")
print(f"2. Load the consolidation map embeddings JSON file") 
print(f"3. Compute cosine similarity between each category and consolidation map keys")
print(f"4. Map categories to the most similar consolidation map key")
