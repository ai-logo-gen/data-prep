# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Set up paths
metadata8_path = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata8.csv')
print(f"Loading metadata8 from: {metadata8_path}")
print(f"File exists: {metadata8_path.exists()}")

if metadata8_path.exists():
    file_size = metadata8_path.stat().st_size / (1024 * 1024)  # MB
    print(f"File size: {file_size:.2f} MB")
# Out:
# Loading metadata8 from: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata8.csv
# File exists: True
# File size: 81.14 MB

# %%
# Load metadata8
try:
    df = pd.read_csv(metadata8_path)
    print(f"✓ Successfully loaded metadata8.csv")
    print(f"Dataset shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print("\nFirst few rows:")
    print(df.head())
except Exception as e:
    print(f"✗ Error loading metadata8.csv: {e}")
# Out:
# ✓ Successfully loaded metadata8.csv
# Dataset shape: (352154, 5)
# Columns: ['id', 'company', 'description', 'category', 'tags']
#
# First few rows:
#                       id                                       company  \
# 0  amazing_logo_v4000000     Simple elegant logo for Mandarin Oriental
# 1  amazing_logo_v4000001                  Simple elegant logo for Alfa
# 2  amazing_logo_v4000003          Simple elegant logo for Valwood Park
# 3  amazing_logo_v4000004               Simple elegant logo for Cinepaq
# 4  amazing_logo_v4000005  Simple elegant logo for Baumechanik Barleben
#
#                        description              category  \
# 0        Fan Hong kong Lines Paper  hospitality_services
# 1         Hexagon Poland Triangles    chemical_materials
# 2    Lines Rounded United states V                  park
# 3  C Circle Film reel Spain Square            film_video
# 4                 B Circle Germany           engineering
#
# ...

# %%
len(df.category.value_counts().index.to_list())
# Out:
# 1622

# %%
print(df.category.value_counts().index.to_list()[-1000:])
# Out:
# ['design_communications', 'stationary_designer', 'candle', 'jewerly', 'design_and_marketing', 'custom_furniture', 'event_marketing', 'community_organization', 'event_space', 'political_consulting', 'family_law', 'wireless_technology', 'decorating_service', 'metal_industry', 'talent_agency', 'monogram', 'hotel_casino', 'environmental_conservation', 'pottery', 'unsold', 'bioscience', 'blogger', 'entertainment_the_arts', 'business_software', 'cargo', 'mobile_software', 'energy_solutions', 'housing_and_land_council', 'wellcrafted_brands', 'art_book', 'software_manufacture', 'sports_hospitality', 'business_association', 'music_club', 'kids_clothing', 'digital_magazines', 'plants', 'sushi_bar', 'parenting', 'pet_supply', 'knitting', 'decor', 'investigation', 'apartment_rental', 'digital_advertising', 'film_music', 'tv_channel', 'transporation', 'food_and_entertainment', 'casual', 'heathcare', 'ceramic', 'fitness_apparel', 'humane_society', 'business_training', '3_tier_auto_financing', 'wal
# ...
