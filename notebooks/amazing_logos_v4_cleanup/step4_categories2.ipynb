# %% [markdown]
# # Amazing Logos V4 - Step 4: Categories Consolidation Using Utils
#
# This notebook consolidates categories using the consolidation utility:
# - Loads metadata3.csv and analyzes categories directly
# - Uses utils/consolidation.py to map categories to consolidated groups
# - Creates analysis3.json with consolidated category analysis
# - Replaces categories in metadata with consolidated ones
# - Creates metadata4.csv with updated consolidated categories

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
from collections import defaultdict

# Add utils folder to path
utils_path = Path('../../utils')
sys.path.append(str(utils_path))

# Import consolidation functions
from consolidation import consolidate_categories, normalize_category, consolidation_map

# Paths
input_metadata_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata5.csv')
output_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/categories_analysis3.json')
output_metadata_csv = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata6.csv')

print(f"Input metadata CSV: {input_metadata_csv}")
print(f"Output categories JSON: {output_csv}")
print(f"Output metadata CSV: {output_metadata_csv}")

# Check if metadata input exists
if not input_metadata_csv.exists():
    print(f"ERROR: Input file {input_metadata_csv} does not exist!")
    print("Please run previous steps to create metadata3.csv.")
else:
    print(f"Input metadata file exists.")
# Out:
# Input metadata CSV: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata5.csv
# Output categories JSON: ..\output\amazing_logos_v4\data\amazing_logos_v4_categories_analysis3.json
# Output metadata CSV: ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata6.csv
# Input metadata file exists.

# %%
consolidation_map.keys()
# Out:
# dict_keys(['real_estate_residential', 'real_estate_commercial', 'real_estate_development', 'construction_general', 'construction_home', 'construction_specialty', 'property_management', 'restaurant_dining', 'cafe_coffee', 'bar_nightlife', 'brewery_alcohol', 'catering_events', 'food_production', 'grocery_retail', 'beverage_general', 'software_development', 'web_digital', 'it_services', 'telecommunications', 'fintech_crypto', 'gaming_entertainment', 'data_analytics', 'tech_hardware', 'healthcare_general', 'dental_services', 'medical_specialty', 'wellness_fitness', 'mental_health', 'veterinary', 'education_k12', 'higher_education', 'training_development', 'childcare_youth', 'educational_services', 'music_industry', 'film_video', 'arts_culture', 'entertainment_venues', 'sports_recreation', 'media_publishing', 'radio_podcast', 'fashion_apparel', 'retail_general', 'ecommerce_online', 'jewelry_accessories', 'footwear_leather', 'textiles_manufacturing', 'legal_services', 'financial_services', 'accounting_tax', 'consulting_business', 'insurance_services', 'marketing_advertising', 'design_creative', 'human_resources', 'manufacturing_general', 'automotive_transport', 'chemical_materials', 'energy_utilities', 'construction_materials', 'beauty_cosmetics', 'salon_spa', 'health_wellness', 'hotels_lodging', 'travel_tourism', 'hospitality_services', 'vacation_recreation', 'nonprofit_charity', 'religious_faith', 'government_public', 'community_social', 'fitness_health', 'sports_teams', 'outdoor_sports', 'martial_arts', 'agriculture_farming', 'environmental_services', 'landscaping_garden', 'pet_services', 'animal_services', 'auto_services', 'vehicle_sales', 'transportation_services', 'home_services', 'home_goods', 'home_improvement', 'lifestyle_personal', 'photography_video', 'printing_publishing', 'security_safety', 'cleaning_maintenance', 'event_services', 'marine_services', 'water_services', 'mining_extraction', 'forestry_lumber', 'aviation_services', 'aerospace_defense', 'import_export', 'wholesale_distribution', 'tobacco_vaping', 'gambling_betting', 'funeral_services', 'tattoo_body_art', 'skateboarding_action', 'other_services', 'personal_professional', 'unclassified', 'tattoo body_art'])

# %%
# Load metadata and create category analysis
print("Loading metadata and analyzing categories...")
df_metadata = pd.read_csv(input_metadata_csv)

print(f"Loaded metadata: {len(df_metadata):,} rows")
print(f"Columns: {list(df_metadata.columns)}")


# Find categories that are only digits
numeric_mask = df_metadata['category'].astype(str).str.match(r'^\d+$', na=False)
numeric_categories = df_metadata[numeric_mask]['category'].tolist()
numeric_count = numeric_mask.sum()

if numeric_count > 0:
    print(f"Found {numeric_count} numeric-only categories")

    
    # Replace numeric categories with NA
    df_metadata.loc[numeric_mask, 'category'] = pd.NA
    print(f"\nReplaced {numeric_count} numeric categories with NA")
    
    # set rows with NA categories for consolidation to 'na' string
    df_metadata.loc[df_metadata.category.isna(), 'category'] = 'na'
else:
    print("No numeric-only categories found")
df_for_consolidation = df_metadata.copy()
# Out:
# Loading metadata and analyzing categories...
# Loaded metadata: 393,298 rows
# Columns: ['id', 'company', 'description', 'category', 'tags']
# Found 632 numeric-only categories
#
# Replaced 632 numeric categories with NA

# %%
# Use consolidation function to get consolidated categories
print("\n=== CONSOLIDATING CATEGORIES ===")
print("Using consolidation.py utility...")

# Apply consolidation to cleaned data (excluding numeric categories)
df_consolidated, unmatched_categories, consolidation_mapping = consolidate_categories(df_for_consolidation)

print(f"\nConsolidation complete!")
print(f"Consolidated categories: {len(consolidation_mapping)}")
print(f"Unmatched categories: {len(unmatched_categories)}")
print(f"Total logos processed: {len(df_consolidated):,}")

# Show some statistics about the consolidation
total_logos = sum(data['count'] for data in consolidation_mapping.values())
print(f"Total logos in consolidation mapping: {total_logos:,}")

print(f"\n=== TOP 10 CONSOLIDATED CATEGORIES ===")
sorted_categories = sorted(consolidation_mapping.items(), key=lambda x: x[1]['count'], reverse=True)
for i, (category, data) in enumerate(sorted_categories[:10], 1):
    percentage = (data['count'] / total_logos) * 100 if total_logos > 0 else 0
    num_originals = len(data['original_categories'])
    print(f"{i:2d}. {category:<30} {data['count']:>7} ({percentage:>5.2f}%) [{num_originals:>3} orig]")
# Out:
# === CONSOLIDATING CATEGORIES ===
# Using consolidation.py utility...
# DEBUG TAG ADD: 'adhesives' -> 'chemical_materials' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'adhesives']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'design']
# DEBUG TAG ADD: 'meat_processing_machinery' -> 'food_production' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'meat_processing_machinery']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'design']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'design']
# DEBUG TAG ADD: 'advertising' -> 'marketing_advertising' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'advertising']
# DEBUG TAG ADD: 'printing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'printing']
# DEBUG TAG ADD: 'newspaper' -> 'media_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'newspaper']
# DEBUG TAG ADD: 'events' -> 'catering_events' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'events']
# DEBUG TAG ADD: 'electronics' -> 'tech_hardware' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'electronics']
# DEBUG TAG ADD: 'interior_design_magazine' -> 'home_improvement' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'interior_design_magazine']
# DEBUG TAG ADD: 'textiles' -> 'textiles_manufacturing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'textiles']
# DEBUG TAG ADD: 'textiles' -> 'textiles_manufacturing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'textiles']
# DEBUG TAG ADD: 'publishing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'publishing']
# DEBUG TAG ADD: 'gardening' -> 'landscaping_garden' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'gardening']
# DEBUG TAG ADD: 'films' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'films']
# DEBUG TAG ADD: 'bakery' -> 'cafe_coffee' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'bakery']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'design']
# DEBUG TAG ADD: 'footwear' -> 'footwear_leather' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'footwear']
# DEBUG TAG ADD: 'interior_design' -> 'home_improvement' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'interior_design']
# DEBUG TAG ADD: 'publishing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'publishing']
# DEBUG TAG ADD: 'clothing' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'clothing']
# DEBUG TAG ADD: 'insurance' -> 'insurance_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'insurance']
# DEBUG TAG ADD: 'broadcasting' -> 'radio_podcast' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'broadcasting']
# DEBUG TAG ADD: 'manufacturing' -> 'manufacturing_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'manufacturing']
# DEBUG TAG ADD: 'furniture' -> 'home_goods' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'furniture']
# DEBUG TAG ADD: 'manufacturing' -> 'manufacturing_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'manufacturing']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'real_estate']
# DEBUG TAG ADD: 'hospital' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'hospital']
# DEBUG TAG ADD: 'automobiles' -> 'automotive_transport' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'automobiles']
# DEBUG TAG ADD: 'university' -> 'higher_education' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'university']
# DEBUG TAG ADD: 'fashion' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'fashion']
# DEBUG TAG ADD: 'publishing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'publishing']
# DEBUG TAG ADD: 'printing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'printing']
# DEBUG TAG ADD: 'road_construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'road_construction']
# DEBUG TAG ADD: 'publishing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'publishing']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'healthcare']
# DEBUG TAG ADD: 'short_film_production_film' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'short_film_production_film']
# DEBUG TAG ADD: 'construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'construction']
# DEBUG TAG ADD: 'printing_offset_letterpress' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'printing_offset_letterpress']
# DEBUG TAG ADD: 'architecture' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'architecture']
# DEBUG TAG ADD: 'textile_company' -> 'textiles_manufacturing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'textile_company']
# DEBUG TAG ADD: 'pharmaceuticals' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'pharmaceuticals']
# DEBUG TAG ADD: 'business' -> 'web_digital' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'business']
# DEBUG TAG ADD: 'construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'construction']
# DEBUG TAG ADD: 'housing' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'housing']
# DEBUG TAG ADD: 'tourism' -> 'travel_tourism' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'tourism']
# DEBUG TAG ADD: 'britain_civil_engineering' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'black_and_white', 'britain_civil_engineering']
# DEBUG TAG ADD: 'fitness' -> 'fitness_health' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fitness']
# DEBUG TAG ADD: 'event_planning' -> 'event_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'event_planning']
# DEBUG TAG ADD: 'building' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'building']
# DEBUG TAG ADD: 'self_promotion' -> 'personal_professional' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'self_promotion']
# DEBUG TAG ADD: 'it' -> 'it_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'it']
# DEBUG TAG ADD: 'community' -> 'community_social' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'community']
# DEBUG TAG ADD: 'interior_design' -> 'home_improvement' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'interior_design']
# DEBUG TAG ADD: 'construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'construction']
# DEBUG TAG ADD: 'photography' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'photography']
# DEBUG TAG ADD: 'beauty_aesthetics' -> 'beauty_cosmetics' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beauty_aesthetics']
# DEBUG TAG ADD: 'commercial_photography' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'commercial_photography']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'non_profit' -> 'nonprofit_charity' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'non_profit']
# DEBUG TAG ADD: 'fitness_sport_health' -> 'fitness_health' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fitness_sport_health']
# DEBUG TAG ADD: 'toys_entertainment' -> 'entertainment_venues' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'toys_entertainment']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'automotive' -> 'automotive_transport' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'automotive']
# DEBUG TAG ADD: 'beauty' -> 'beauty_cosmetics' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beauty']
# DEBUG TAG ADD: 'photographer' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'photographer']
# DEBUG TAG ADD: 'ballett' -> 'arts_culture' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'ballett']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'it_security_software_and_solutions' -> 'it_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'it_security_software_and_solutions']
# DEBUG TAG ADD: 'advertising' -> 'marketing_advertising' | Tags: ['direct_mail', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'advertising']
# DEBUG TAG ADD: 'automotive' -> 'automotive_transport' | Tags: ['event', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'automotive']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'jewelry' -> 'jewelry_accessories' | Tags: ['fashion', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'jewelry']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'underwater_photography' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'underwater_photography']
# DEBUG TAG ADD: 'fitness' -> 'fitness_health' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fitness']
# DEBUG TAG ADD: 'digital' -> 'web_digital' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'digital']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'restaurant' -> 'restaurant_dining' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'restaurant']
# DEBUG TAG ADD: 'environmental' -> 'environmental_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'environmental']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'publishing' -> 'printing_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'publishing']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'sports' -> 'sports_recreation' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'sports']
# DEBUG TAG ADD: 'health_and_fitness' -> 'fitness_health' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'health_and_fitness']
# DEBUG TAG ADD: 'photography' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'photography']
# DEBUG TAG ADD: 'automotive' -> 'automotive_transport' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'automotive']
# DEBUG TAG ADD: 'pharmaceuticals' -> 'medical_specialty' | Tags: ['drug_development', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'pharmaceuticals']
# DEBUG TAG ADD: 'education' -> 'education_k12' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'education']
# DEBUG TAG ADD: 'radio' -> 'radio_podcast' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'radio']
# DEBUG TAG ADD: 'garage_door' -> 'home_improvement' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'garage_door']
# DEBUG TAG ADD: 'consulting' -> 'other_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'consulting']
# DEBUG TAG ADD: 'beverage' -> 'beverage_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beverage']
# DEBUG TAG ADD: 'photography' -> 'photography_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'photography']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'creative' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'creative']
# DEBUG TAG ADD: 'advertising' -> 'marketing_advertising' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'advertising']
# DEBUG TAG ADD: 'pharmaceutical' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'pharmaceutical']
# DEBUG TAG ADD: 'educational' -> 'education_k12' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'educational']
# DEBUG TAG ADD: 'fashion' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fashion']
# DEBUG TAG ADD: 'tea' -> 'beverage_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'tea']
# DEBUG TAG ADD: 'education' -> 'education_k12' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'education']
# DEBUG TAG ADD: 'beverage' -> 'beverage_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beverage']
# DEBUG TAG ADD: 'fashion' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fashion']
# DEBUG TAG ADD: 'internet' -> 'web_digital' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'internet']
# DEBUG TAG ADD: 'salon_hair_designer' -> 'salon_spa' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'salon_hair_designer']
# DEBUG TAG ADD: 'theater' -> 'arts_culture' | Tags: ['theatre', 'arts', 'nonprofit', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'theater']
# DEBUG TAG ADD: 'online_shopping' -> 'ecommerce_online' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'online_shopping']
# DEBUG TAG ADD: 'online_games' -> 'gaming_entertainment' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'online_games']
# DEBUG TAG ADD: 'bakery' -> 'cafe_coffee' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'bakery']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'apparel' -> 'fashion_apparel' | Tags: ['garment', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'apparel']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'hospitality' -> 'hospitality_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'hospitality']
# DEBUG TAG ADD: 'travel' -> 'travel_tourism' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'travel']
# DEBUG TAG ADD: 'education' -> 'education_k12' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'education']
# DEBUG TAG ADD: 'tool_and_die' -> 'manufacturing_general' | Tags: ['machining', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'tool_and_die']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'restaurant' -> 'restaurant_dining' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'restaurant']
# DEBUG TAG ADD: 'entertainment' -> 'entertainment_venues' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'entertainment']
# DEBUG TAG ADD: 'urban_development' -> 'real_estate_development' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'urban_development']
# DEBUG TAG ADD: 'video' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'video']
# DEBUG TAG ADD: 'travel' -> 'travel_tourism' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'travel']
# DEBUG TAG ADD: 'childcare' -> 'childcare_youth' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'childcare']
# DEBUG TAG ADD: 'cleaning' -> 'home_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'cleaning']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'design']
# DEBUG TAG ADD: 'music' -> 'music_industry' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'music']
# DEBUG TAG ADD: 'health_research' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'health_research']
# DEBUG TAG ADD: 'architecture' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'architecture']
# DEBUG TAG ADD: 'athletics' -> 'sports_teams' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'athletics']
# DEBUG TAG ADD: 'funeral' -> 'funeral_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'funeral']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'beauty' -> 'beauty_cosmetics' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beauty']
# DEBUG TAG ADD: 'ngo' -> 'nonprofit_charity' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'ngo']
# DEBUG TAG ADD: 'environmental' -> 'environmental_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'environmental']
# DEBUG TAG ADD: 'apartments' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'apartments']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'commercial_property' -> 'real_estate_commercial' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'commercial_property']
# DEBUG TAG ADD: 'music' -> 'music_industry' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'music']
# DEBUG TAG ADD: 'med_tech' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'med_tech']
# DEBUG TAG ADD: 'pharma' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'pharma']
# DEBUG TAG ADD: 'sports' -> 'sports_recreation' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'sports']
# DEBUG TAG ADD: 'internet' -> 'web_digital' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'internet']
# DEBUG TAG ADD: 'creative' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'creative']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'television' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'television']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'design']
# DEBUG TAG ADD: 'fashion' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'fashion']
# DEBUG TAG ADD: 'religion' -> 'religious_faith' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'religion']
# DEBUG TAG ADD: 'hospitality' -> 'hospitality_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'hospitality']
# DEBUG TAG ADD: 'interior_design_arts' -> 'home_improvement' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'interior_design_arts']
# DEBUG TAG ADD: 'sports' -> 'sports_recreation' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'sports']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['security', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'cycling' -> 'outdoor_sports' | Tags: ['apparel', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'cycling']
# DEBUG TAG ADD: 'entertainment' -> 'entertainment_venues' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'entertainment']
# DEBUG TAG ADD: 'nonprofit' -> 'nonprofit_charity' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'nonprofit']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'non_profit_organization' -> 'educational_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'non_profit_organization']
# DEBUG TAG ADD: 'film_and_tv_production' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'film_and_tv_production']
# DEBUG TAG ADD: 'childcare' -> 'childcare_youth' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'childcare']
# DEBUG TAG ADD: 'restaurant' -> 'restaurant_dining' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'restaurant']
# DEBUG TAG ADD: 'motorsports' -> 'sports_recreation' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'motorsports']
# DEBUG TAG ADD: 'mobile_application' -> 'software_development' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'mobile_application']
# DEBUG TAG ADD: 'church' -> 'religious_faith' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'church']
# DEBUG TAG ADD: 'communication' -> 'telecommunications' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'communication']
# DEBUG TAG ADD: 'marketing' -> 'marketing_advertising' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'marketing']
# DEBUG TAG ADD: 'construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'construction']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'design']
# DEBUG TAG ADD: 'social_services' -> 'nonprofit_charity' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'social_services']
# DEBUG TAG ADD: 'entertainment' -> 'entertainment_venues' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'entertainment']
# DEBUG TAG ADD: 'hospitality' -> 'hospitality_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'hospitality']
# DEBUG TAG ADD: 'travel' -> 'travel_tourism' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'travel']
# DEBUG TAG ADD: 'residential_real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'residential_real_estate']
# DEBUG TAG ADD: 'church' -> 'religious_faith' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'church']
# DEBUG TAG ADD: 'bathrooms' -> 'home_goods' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'bathrooms']
# DEBUG TAG ADD: 'non_profit_program' -> 'nonprofit_charity' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'non_profit_program']
# DEBUG TAG ADD: 'art' -> 'arts_culture' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'art']
# DEBUG TAG ADD: 'it' -> 'it_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'it']
# DEBUG TAG ADD: 'beverage' -> 'beverage_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'beverage']
# DEBUG TAG ADD: 'service' -> 'other_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'service']
# DEBUG TAG ADD: 'film' -> 'film_video' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'film']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'hospitality' -> 'hospitality_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'hospitality']
# DEBUG TAG ADD: 'transportation' -> 'transportation_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'transportation']
# DEBUG TAG ADD: 'multi_family_residential_real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'multi_family_residential_real_estate']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'design']
# DEBUG TAG ADD: 'pet_care' -> 'pet_services' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'pet_care']
# DEBUG TAG ADD: 'web_site' -> 'media_publishing' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'web_site']
# DEBUG TAG ADD: 'construction_company' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'construction_company']
# DEBUG TAG ADD: 'entertainment' -> 'entertainment_venues' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'entertainment']
# DEBUG TAG ADD: 'advertising' -> 'marketing_advertising' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'advertising']
# DEBUG TAG ADD: 'hotel' -> 'hotels_lodging' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'hotel']
# DEBUG TAG ADD: 'advertising' -> 'marketing_advertising' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'advertising']
# DEBUG TAG ADD: 'real_estate' -> 'real_estate_residential' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'real_estate']
# DEBUG TAG ADD: 'design' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'design']
# DEBUG TAG ADD: 'technology' -> 'medical_specialty' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'technology']
# DEBUG TAG ADD: 'golf' -> 'outdoor_sports' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'golf']
# DEBUG TAG ADD: 'tourism' -> 'travel_tourism' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'tourism']
# DEBUG TAG ADD: 'creative' -> 'design_creative' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'creative']
# DEBUG TAG ADD: 'jewelry' -> 'jewelry_accessories' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'jewelry']
# DEBUG TAG ADD: 'healthcare' -> 'healthcare_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'healthcare']
# DEBUG TAG ADD: 'construction' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'construction']
# DEBUG TAG ADD: 'building_products' -> 'construction_materials' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'building_products']
# DEBUG TAG ADD: 'tax_preparation' -> 'accounting_tax' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'tax_preparation']
# DEBUG TAG ADD: 'restaurant' -> 'restaurant_dining' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'restaurant']
# DEBUG TAG ADD: 'garment' -> 'fashion_apparel' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'garment']
# DEBUG TAG ADD: 'coffee' -> 'cafe_coffee' | Tags: ['entertainment', 'successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'coffee']
# DEBUG TAG ADD: 'personal' -> 'personal_professional' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'personal']
# DEBUG TAG ADD: 'contractor' -> 'construction_general' | Tags: ['successful_vibe', 'minimalist', 'thoughtprovoking', 'abstract', 'recognizable', 'relatable', 'sharp', 'vector_art', 'even_edges', 'contractor']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 print("Using consolidation.py utility...")
#       5 # Apply consolidation to cleaned data (excluding numeric categories)
# ----> 6 df_consolidated, unmatched_categories, consolidation_mapping = consolidate_categories(df_for_consolidation)
#       8 print(f"\nConsolidation complete!")
#       9 print(f"Consolidated categories: {len(consolidation_mapping)}")
#
# File c:\studium\masterarbeit\data_prep\notebooks\..\utils\consolidation.py:150, in consolidate_categories(df)
#     147     return row
#     149 # Apply the processing to each row
# --> 150 result_df = result_df.apply(process_row, axis=1)
#     152 return result_df, unmatched_categories, dict(consolidation_mapping)
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)  10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\paul-\anaconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\studium\masterarbeit\data_prep\notebooks\..\utils\consolidation.py:121, in consolidate_categories.<locals>.process_row(row)
#     119 def process_row(row):
#     120     original_category = row['category']
# --> 121     consolidated_category = map_category(original_category)
#     123     # Update the category
#     124     row['category'] = consolidated_category
#
# File c:\studium\masterarbeit\data_prep\notebooks\..\utils\consolidation.py:70, in consolidate_categories.<locals>.map_category(category)
#      68 overlap = 0
#      69 norm_words = set(normalized.split())
# ---> 70 cat_words = set(norm_cat.split())
#      72 # Only proceed if there are actual words to compare
#      73 if not norm_words or not cat_words:
#
# KeyboardInterrupt:

# %%
# Create the final DataFrame with required format
print("\n=== CREATING FINAL OUTPUT ===")

final_data = []
for category, data in consolidation_mapping.items():
    # Join original categories with commas
    original_categories_str = ', '.join(sorted(set(data['original_categories'])))
    
    final_data.append({
        'category': category,
        'count': data['count'],
        'original_categories': original_categories_str
    })

# Create DataFrame and sort by count
df_final = pd.DataFrame(final_data)
df_final = df_final.sort_values('count', ascending=False).reset_index(drop=True)

print(f"Created final DataFrame with {len(df_final)} consolidated categories")
print(f"Total logos: {df_final['count'].sum():,}")

# Show top consolidated categories
print(f"\n=== TOP 20 CONSOLIDATED CATEGORIES ===")
for i, row in df_final.head(20).iterrows():
    percentage = (row['count'] / df_final['count'].sum()) * 100
    num_originals = len(row['original_categories'].split(', '))
    print(f"{i+1:2d}. {row['category']:<30} {row['count']:>7} ({percentage:>5.2f}%) [{num_originals:>3} orig]")
# Out:
# === CREATING FINAL OUTPUT ===
# Created final DataFrame with 41807 consolidated categories
# Total logos: 393,297
#
# === TOP 20 CONSOLIDATED CATEGORIES ===
#  1. unclassified                     27314 ( 6.94%) [ 19 orig]
#  2. real_estate_residential          10515 ( 2.67%) [212 orig]
#  3. restaurant_dining                10304 ( 2.62%) [176 orig]
#  4. healthcare_general                9870 ( 2.51%) [ 94 orig]
#  5. nonprofit_charity                 9831 ( 2.50%) [205 orig]
#  6. design_creative                   9756 ( 2.48%) [206 orig]
#  7. sports_recreation                 9274 ( 2.36%) [ 24 orig]
#  8. education_k12                     8275 ( 2.10%) [ 38 orig]
#  9. fashion_apparel                   8054 ( 2.05%) [ 37 orig]
# 10. food                              7863 ( 2.00%) [  1 orig]
# 11. medical_specialty                 6652 ( 1.69%) [ 44 orig]
# 12. music_industry                    6628 ( 1.69%) [ 53 orig]
# 13. retail_general                    5682 ( 1.44%) [ 36 orig]
# 14. construction_general              5537 ( 1.41%) [ 71 orig]
# 15. entertainment_venues              5455 ( 1.39%) [ 41 orig]
# 16. marketing_advertising             5395 ( 1.37%) [ 95 orig]
# 17. financial_services                4623 ( 1.18%) [ 60 orig]
# 18. photography_video                 4473 ( 1.14%) [ 38 orig]
# 19. arts_culture                      4256 ( 1.08%) [ 63 orig]
# 20. other_services                    3954 ( 1.01%) [ 52 orig]

# %%
# Save the consolidated analysis
print(f"\nSaving consolidated analysis to {output_csv}...")

# Create category analysis from consolidation mapping
original_categories_count = len(set(cat for data in consolidation_mapping.values() for cat in data['original_categories']))

# Create JSON-friendly output with explicit type conversion to avoid int64 serialization issues
output_data = {
    "metadata": {
        "original_categories_count": int(original_categories_count),
        "numeric_categories_removed": int(numeric_count if 'numeric_count' in locals() else 0),
        "categories_after_cleaning": int(len(df_for_consolidation)),
        "final_consolidated_categories": int(len(df_final)),
        "total_reduction_factor": float(round(original_categories_count / len(df_final), 1)),
        "total_logos": int(df_final['count'].sum()),
        "consolidation_timestamp": pd.Timestamp.now().isoformat()
    },
    "consolidated_categories": []
}

# Add consolidated categories data with explicit type conversion
for _, row in df_final.iterrows():
    output_data["consolidated_categories"].append({
        "category": str(row['category']),
        "count": int(row['count']),
        "percentage": float(round((row['count'] / df_final['count'].sum()) * 100, 2)),
        "original_categories": [str(cat.strip()) for cat in row['original_categories'].split(', ')]
    })

# Save as JSON
import json
with open(output_csv, 'w', encoding='utf-8') as f:
    json.dump(output_data, f, indent=2, ensure_ascii=False)

print(f"Consolidated analysis saved successfully as JSON!")

# Show final statistics
print(f"\n=== FINAL STATISTICS ===")
print(f"Original categories (before cleaning): {original_categories_count:,}")
print(f"Numeric categories removed: {numeric_count if 'numeric_count' in locals() else 0}")
print(f"Categories after cleaning: {len(df_for_consolidation):,}")
print(f"Final consolidated categories: {len(df_final)}")
print(f"Total reduction factor: {original_categories_count / len(df_final):.1f}x")
print(f"Total logos: {df_final['count'].sum():,}")
print(f"Output file: {output_csv}")
print(f"Columns: {list(df_final.columns)}")

# Show some examples of the mapping
print(f"\n=== SAMPLE MAPPING EXAMPLES ===")
for i, row in df_final.head(5).iterrows():
    original_list = row['original_categories'].split(', ')[:5]  # Show first 5 original categories
    print(f"\n{row['category']} ({row['count']} logos):")
    for orig in original_list:
        print(f"  - {orig}")
    if len(row['original_categories'].split(', ')) > 5:
        remaining = len(row['original_categories'].split(', ')) - 5
        print(f"  ... and {remaining} more")
# Out:
# Saving consolidated analysis to ..\output\amazing_logos_v4\data\amazing_logos_v4_categories_analysis3.json...
# Consolidated analysis saved successfully as JSON!
#
# === FINAL STATISTICS ===
# Original categories (before cleaning): 46,070
# Numeric categories removed: 617
# Categories after cleaning: 393,297
# Final consolidated categories: 41807
# Total reduction factor: 1.1x
# Total logos: 393,297
# Output file: ..\output\amazing_logos_v4\data\amazing_logos_v4_categories_analysis3.json
# Columns: ['category', 'count', 'original_categories']
#
# === SAMPLE MAPPING EXAMPLES ===
#
# unclassified (27314 logos):
#   - all
#   - call
#   - defined
#   - mall
#   - misc
#   ... and 14 more
#
# real_estate_residential (10515 logos):
#   - adult_living
#   - apartment
#   - apartment_real_estate
#   - apartments
#   - architectural_real_estate
#   ... and 207 more
#
# restaurant_dining (10304 logos):
#   - airline_food_service
#   - asian_cuisine
#   - asian_fast_food
#   - bakery_food_service
#   - bar_and_restaurant
#   ... and 171 more
#
# healthcare_general (9870 logos):
#   - ag_medicine
#   - air_medical_services
#   - child_health_care
#   - child_health_services
#   - clinic
#   ... and 89 more
#
# nonprofit_charity (9831 logos):
#   - adoption_non_profit
#   - advertising_non_profit
#   - advocacy_non_profit
#   - african_non_profit
#   - agriculture_non_profit
#   ... and 200 more

# %%
# Apply consolidation to metadata3.csv to create metadata4.csv
print(f"\n=== APPLYING CONSOLIDATION TO METADATA ===")
print(f"Using metadata already loaded from {input_metadata_csv}...")

print(f"Metadata: {len(df_metadata):,} rows")
print(f"Columns: {list(df_metadata.columns)}")

# Create mapping dictionary from original to consolidated categories
category_mapping = {}
for _, row in df_final.iterrows():
    consolidated_cat = row['category']
    original_cats = row['original_categories'].split(', ')
    for orig_cat in original_cats:
        category_mapping[orig_cat.strip()] = consolidated_cat

# Also handle numeric categories
if 'numeric_categories' in [row['category'] for _, row in df_final.iterrows()]:
    for num_cat in numeric_categories:
        category_mapping[str(num_cat)] = 'numeric_categories'

print(f"Created mapping for {len(category_mapping)} original categories")

# Apply consolidation to metadata
df_metadata_consolidated = df_metadata.copy()

# Track consolidation statistics
original_categories_in_metadata = df_metadata_consolidated['category'].value_counts()
consolidation_stats = {'mapped': 0, 'unmapped': 0, 'na_values': 0}

def consolidate_category(category):
    """Apply consolidation mapping to a single category"""
    if pd.isna(category):
        consolidation_stats['na_values'] += 1
        return pd.NA
    
    category_str = str(category).strip()
    if category_str in category_mapping:
        consolidation_stats['mapped'] += 1
        return category_mapping[category_str]
    else:
        consolidation_stats['unmapped'] += 1
        return 'unclassified'

# Apply consolidation
print("Applying category consolidation to metadata...")
df_metadata_consolidated['category'] = df_metadata_consolidated['category'].apply(consolidate_category)

print(f"\n=== CONSOLIDATION STATISTICS ===")
print(f"Categories mapped to consolidated: {consolidation_stats['mapped']:,}")
print(f"Categories mapped to 'unclassified': {consolidation_stats['unmapped']:,}")
print(f"NA values preserved: {consolidation_stats['na_values']:,}")
print(f"Total rows processed: {len(df_metadata_consolidated):,}")

# Show before/after category distribution
print(f"\n=== CATEGORY DISTRIBUTION COMPARISON ===")
print(f"Original unique categories: {df_metadata['category'].nunique()}")
print(f"Consolidated unique categories: {df_metadata_consolidated['category'].nunique()}")

print(f"\nTop 10 consolidated categories in metadata:")
consolidated_counts = df_metadata_consolidated['category'].value_counts().head(10)
for i, (cat, count) in enumerate(consolidated_counts.items(), 1):
    percentage = (count / len(df_metadata_consolidated)) * 100
    print(f"{i:2d}. {cat:<25} {count:>7} ({percentage:>5.2f}%)")

# Save consolidated metadata
print(f"\nSaving consolidated metadata to {output_metadata_csv}...")
df_metadata_consolidated.to_csv(output_metadata_csv, index=False)
print(f"Consolidated metadata saved successfully!")

print(f"\n=== FINAL OUTPUT FILES ===")
print(f"Categories analysis (JSON): {output_csv}")
print(f"Consolidated metadata (CSV): {output_metadata_csv}")
print(f"Total logos with consolidated categories: {len(df_metadata_consolidated):,}")
# Out:
# === APPLYING CONSOLIDATION TO METADATA ===
# Using metadata already loaded from ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata5.csv...
# Metadata: 393,297 rows
# Columns: ['id', 'company', 'description', 'category', 'tags']
# Created mapping for 46070 original categories
# Applying category consolidation to metadata...
# Created mapping for 46070 original categories
# Applying category consolidation to metadata...
#
# === CONSOLIDATION STATISTICS ===
# Categories mapped to consolidated: 393,297
# Categories mapped to 'unclassified': 0
# NA values preserved: 0
# Total rows processed: 393,297
#
# === CATEGORY DISTRIBUTION COMPARISON ===
# Original unique categories: 46070
# Consolidated unique categories: 41807
#
# Top 10 consolidated categories in metadata:
#  1. unclassified                27314 ( 6.94%)
#  2. real_estate_residential     10515 ( 2.67%)
#  3. restaurant_dining           10304 ( 2.62%)
#  4. healthcare_general           9870 ( 2.51%)
#  5. nonprofit_charity            9831 ( 2.50%)
#  6. design_creative              9756 ( 2.48%)
#  7. sports_recreation            9274 ( 2.36%)
#  8. education_k12                8275 ( 2.10%)
#  9. fashion_apparel              8054 ( 2.05%)
# 10. food                         7863 ( 2.00%)
#
# Saving consolidated metadata to ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata6.csv...
#
# === CONSOLIDATION STATISTICS ===
# Categories mapped to consolidated: 393,297
# Categories mapped to 'unclassified': 0
# NA values preserved: 0
# Total rows processed: 393,297
#
# === CATEGORY DISTRIBUTION COMPARISON ===
# Original unique categories: 46070
# Consolidated unique categories: 41807
#
# Top 10 consolidated categories in metadata:
#  1. unclassified                27314 ( 6.94%)
#  2. real_estate_residential     10515 ( 2.67%)
#  3. restaurant_dining           10304 ( 2.62%)
#  4. healthcare_general           9870 ( 2.51%)
#  5. nonprofit_charity            9831 ( 2.50%)
#  6. design_creative              9756 ( 2.48%)
#  7. sports_recreation            9274 ( 2.36%)
#  8. education_k12                8275 ( 2.10%)
#  9. fashion_apparel              8054 ( 2.05%)
# 10. food                         7863 ( 2.00%)
#
# Saving consolidated metadata to ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata6.csv...
# Consolidated metadata saved successfully!
#
# === FINAL OUTPUT FILES ===
# Categories analysis (JSON): ..\output\amazing_logos_v4\data\amazing_logos_v4_categories_analysis3.json
# Consolidated metadata (CSV): ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata6.csv
# Total logos with consolidated categories: 393,297
# Consolidated metadata saved successfully!
#
# === FINAL OUTPUT FILES ===
# Categories analysis (JSON): ..\output\amazing_logos_v4\data\amazing_logos_v4_categories_analysis3.json
# Consolidated metadata (CSV): ..\output\amazing_logos_v4\data\amazing_logos_v4_metadata6.csv
# Total logos with consolidated categories: 393,297
