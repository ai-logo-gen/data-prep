# %%
import pandas as pd
from pathlib import Path

# %%
metadata_path = Path('../../output/amazing_logos_v4/data/amazing_logos_v4_cleanup/metadata9.csv')

# %%
# Load complete metadata for all images
print("Loading complete metadata...")

# Load full metadata (only id and category columns for efficiency)
metadata_df = pd.read_csv(metadata_path)
# Out:
# Loading complete metadata...

# %%
len(metadata_df)
# Out:
# 352173

# %%
# Filtere Zeilen, bei denen die Spalte 'tags' den Wert 'minimalist' enthält
minimalist_df = metadata_df[metadata_df['tags'].str.contains('minimalist', na=False)]

# Zähle die Anzahl der gefilterten Zeilen
count = len(minimalist_df)

print(f"Anzahl der Zeilen mit 'minimalist' im Tag: {count}")

# Zeige das gefilterte DataFrame an
minimalist_df
# Out:
# Anzahl der Zeilen mit 'minimalist' im Tag: 352173
#                            id                                         company  \
# 0       amazing_logo_v4000000       Simple elegant logo for Mandarin Oriental
# 1       amazing_logo_v4000001                    Simple elegant logo for Alfa
# 2       amazing_logo_v4000003            Simple elegant logo for Valwood Park
# 3       amazing_logo_v4000004                 Simple elegant logo for Cinepaq
# 4       amazing_logo_v4000005    Simple elegant logo for Baumechanik Barleben
# ...                       ...                                             ...
# 352168  amazing_logo_v4397245    Simple elegant logo for Starguard The Dragon
# 352169  amazing_logo_v4397246            Simple elegant logo for Peak2Pacific
# 352170  amazing_logo_v4397248           Simple elegant logo for Elite Angling
# 352171  amazing_logo_v4397249          Simple elegant logo for Jacki Ms & Son
# ...
